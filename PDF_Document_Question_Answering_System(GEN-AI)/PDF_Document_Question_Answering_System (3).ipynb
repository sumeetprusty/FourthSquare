# %% [markdown]
# # Installs

# %%
# !pip install -r req.txt
# Out:
# Collecting cassandra-driver (from -r req.txt (line 1))
#   Downloading cassandra_driver-3.29.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.9/18.9 MB 24.6 MB/s eta 0:00:00
# Collecting langchain (from -r req.txt (line 2))
#   Downloading langchain-0.2.6-py3-none-any.whl (975 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 975.5/975.5 kB 62.0 MB/s eta 0:00:00
# Collecting cohere (from -r req.txt (line 3))
#   Downloading cohere-5.5.8-py3-none-any.whl (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.8/173.8 kB 23.9 MB/s eta 0:00:00
# Collecting pypdf (from -r req.txt (line 4))
#   Downloading pypdf-4.2.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 38.6 MB/s eta 0:00:00
# Collecting cassio>=0.1.1 (from -r req.txt (line 5))
#   Downloading cassio-0.1.8-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 6.3 MB/s eta 0:00:00
# Collecting tiktoken==0.4.0 (from -r req.txt (line 6))
#   Downloading tiktoken-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 80.1 MB/s eta 0:00:00
# Collecting astrapy (from -r req.txt (line 7))
#   Downloading astrapy-1.3.1-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.4/145.4 kB 21.3 MB/s eta 0:00:00
# Collecting PyPDF2 (from -r req.txt (line 8))
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 31.0 MB/s eta 0:00:00
# Collecting langchain_community (from -r req.txt (line 9))
#   Downloading langchain_community-0.2.6-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 76.0 MB/s eta 0:00:00
# Collecting python-dotenv (from -r req.txt (line 10))
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken==0.4.0->-r req.txt (line 6)) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken==0.4.0->-r req.txt (line 6)) (2.31.0)
# Collecting geomet<0.3,>=0.1 (from cassandra-driver->-r req.txt (line 1))
#   Downloading geomet-0.2.1.post1-py3-none-any.whl (18 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain->-r req.txt (line 2)) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain->-r req.txt (line 2)) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain->-r req.txt (line 2)) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain->-r req.txt (line 2)) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.10 (from langchain->-r req.txt (line 2))
#   Downloading langchain_core-0.2.11-py3-none-any.whl (337 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.4/337.4 kB 41.9 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain->-r req.txt (line 2))
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain->-r req.txt (line 2))
#   Downloading langsmith-0.1.83-py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.5/127.5 kB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain->-r req.txt (line 2)) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain->-r req.txt (line 2)) (2.7.4)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain->-r req.txt (line 2)) (8.4.2)
# Collecting boto3<2.0.0,>=1.34.0 (from cohere->-r req.txt (line 3))
#   Downloading boto3-1.34.138-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 19.1 MB/s eta 0:00:00
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere->-r req.txt (line 3))
#   Downloading fastavro-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 83.2 MB/s eta 0:00:00
# Collecting httpx>=0.21.2 (from cohere->-r req.txt (line 3))
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.5 MB/s eta 0:00:00
# Collecting httpx-sse<0.5.0,>=0.4.0 (from cohere->-r req.txt (line 3))
#   Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Collecting parameterized<0.10.0,>=0.9.0 (from cohere->-r req.txt (line 3))
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: tokenizers<1,>=0.15 in /usr/local/lib/python3.10/dist-packages (from cohere->-r req.txt (line 3)) (0.19.1)
# Collecting types-requests<3.0.0,>=2.0.0 (from cohere->-r req.txt (line 3))
#   Downloading types_requests-2.32.0.20240622-py3-none-any.whl (15 kB)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere->-r req.txt (line 3)) (4.12.2)
# Collecting bson<0.6.0,>=0.5.10 (from astrapy->-r req.txt (line 7))
#   Downloading bson-0.5.10.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting deprecation<2.2.0,>=2.1.0 (from astrapy->-r req.txt (line 7))
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from astrapy->-r req.txt (line 7)) (0.10.2)
# Collecting uuid6<2024.2.0,>=2024.1.12 (from astrapy->-r req.txt (line 7))
#   Downloading uuid6-2024.1.12-py3-none-any.whl (6.4 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community->-r req.txt (line 9))
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r req.txt (line 2)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r req.txt (line 2)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r req.txt (line 2)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r req.txt (line 2)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r req.txt (line 2)) (1.9.4)
# Collecting botocore<1.35.0,>=1.34.138 (from boto3<2.0.0,>=1.34.0->cohere->-r req.txt (line 3))
#   Downloading botocore-1.34.138-py3-none-any.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 52.5 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0.0,>=1.34.0->cohere->-r req.txt (line 3))
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<2.0.0,>=1.34.0->cohere->-r req.txt (line 3))
#   Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from bson<0.6.0,>=0.5.10->astrapy->-r req.txt (line 7)) (2.8.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bson<0.6.0,>=0.5.10->astrapy->-r req.txt (line 7)) (1.16.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r req.txt (line 9))
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 7.4 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r req.txt (line 9))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation<2.2.0,>=2.1.0->astrapy->-r req.txt (line 7)) (24.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from geomet<0.3,>=0.1->cassandra-driver->-r req.txt (line 1)) (8.1.7)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere->-r req.txt (line 3)) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere->-r req.txt (line 3)) (2024.6.2)
# Collecting httpcore==1.* (from httpx>=0.21.2->cohere->-r req.txt (line 3))
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere->-r req.txt (line 3)) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere->-r req.txt (line 3)) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.21.2->cohere->-r req.txt (line 3))
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.8 MB/s eta 0:00:00
# Collecting h2<5,>=3 (from httpx>=0.21.2->cohere->-r req.txt (line 3))
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 8.0 MB/s eta 0:00:00
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.10->langchain->-r req.txt (line 2))
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain->-r req.txt (line 2))
#   Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain->-r req.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain->-r req.txt (line 2)) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.4.0->-r req.txt (line 6)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.4.0->-r req.txt (line 6)) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain->-r req.txt (line 2)) (3.0.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers<1,>=0.15->cohere->-r req.txt (line 3)) (0.23.4)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx>=0.21.2->cohere->-r req.txt (line 3))
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx>=0.21.2->cohere->-r req.txt (line 3))
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere->-r req.txt (line 3)) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere->-r req.txt (line 3)) (2023.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere->-r req.txt (line 3)) (4.66.4)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.10->langchain->-r req.txt (line 2))
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community->-r req.txt (line 9))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.21.2->cohere->-r req.txt (line 3)) (1.2.1)
# Building wheels for collected packages: bson
#   Building wheel for bson (setup.py) ... done
#   Created wheel for bson: filename=bson-0.5.10-py3-none-any.whl size=11976 sha256=9afeb049ca622fa2683d82b69b32d7b7a42504bdc8195b85b1b5da16f79bf263
#   Stored in directory: /root/.cache/pip/wheels/36/49/3b/8b33954dfae7a176009c4d721a45af56c8a9c1cdc3ee947945
# Successfully built bson
# Installing collected packages: uuid6, types-requests, python-dotenv, PyPDF2, pypdf, parameterized, orjson, mypy-extensions, marshmallow, jsonpointer, jmespath, hyperframe, httpx-sse, hpack, h11, geomet, fastavro, deprecation, typing-inspect, tiktoken, jsonpatch, httpcore, h2, cassandra-driver, bson, botocore, s3transfer, langsmith, httpx, dataclasses-json, cassio, langchain-core, boto3, langchain-text-splitters, cohere, astrapy, langchain, langchain_community
# Successfully installed PyPDF2-3.0.1 astrapy-1.3.1 boto3-1.34.138 botocore-1.34.138 bson-0.5.10 cassandra-driver-3.29.1 cassio-0.1.8 cohere-5.5.8 dataclasses-json-0.6.7 deprecation-2.1.0 fastavro-1.9.4 geomet-0.2.1.post1 h11-0.14.0 h2-4.1.0 hpack-4.0.0 httpcore-1.0.5 httpx-0.27.0 httpx-sse-0.4.0 hyperframe-6.0.1 jmespath-1.0.1 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.6 langchain-core-0.2.11 langchain-text-splitters-0.2.2 langchain_community-0.2.6 langsmith-0.1.83 marshmallow-3.21.3 mypy-extensions-1.0.0 orjson-3.10.6 parameterized-0.9.0 pypdf-4.2.0 python-dotenv-1.0.1 s3transfer-0.10.2 tiktoken-0.4.0 types-requests-2.32.0.20240622 typing-inspect-0.9.0 uuid6-2024.1.12

# %% [markdown]
# # Importing Cassandra

# %%
import cassandra
print (cassandra.__version__)
# Out:
# 3.29.1

# %% [markdown]
# Here it is connecting to a Cassandra database hosted on Datastax Astra :
#
#
# *   Cluster and PlainTextAuthProvider are classes from the cassandra library used to connect to a Cassandra database.
# *   cloud_config is a dictionary containing the path to the secure connect bundle. This bundle is a ZIP file provided by Datastax Astra to securely connect to their managed Cassandra database.
# *  The JSON file that contains the credentials is loaded into a dictionary called secrets.
# *  The clientId and secret are extracted from the secrets dictionary, which are necessary for authentication.
# *  Then we create a Cluster object with the cloud configuration and authentication provider, and then establishes a session with the Cassandra cluster.

# %%
# Load environment variables from .env file
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
CLIENT_ID = os.getenv("CLIENT_ID")
CLIENT_SECRET = os.getenv("CLIENT_SECRET")
COHERE_API_KEY = os.getenv("COHERE_API_KEY")
ASTRA_DB_TOKEN = os.getenv("ASTRA_DB_TOKEN")
ASTRA_DB_ENDPOINT = os.getenv("ASTRA_DB_ENDPOINT")

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
import json

cloud_config= {
  'secure_connect_bundle': 'secure-connect-sumeet.zip'
}

with open("sumeet-token.json") as f:
    secrets = json.load(f)

CLIENT_ID = secrets["clientId"]
CLIENT_SECRET = secrets["secret"]

auth_provider = PlainTextAuthProvider(CLIENT_ID, CLIENT_SECRET)
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

row = session.execute("select release_version from system.local").one()
if row:
  print(row[0])
else:
  print("An error occurred.")
# Out:
# WARNING:cassandra.cluster:Downgrading core protocol version from 66 to 65 for 4a1c36e1-80dc-415c-bbba-3d05e2197013-us-east1.db.astra.datastax.com:29042:3b8afe0a-9b27-48ef-af55-d95b0aef8e45. To avoid this, it is best practice to explicitly set Cluster(protocol_version) to the version supported by your cluster. http://datastax.github.io/python-driver/api/cassandra/cluster.html#cassandra.cluster.Cluster.protocol_version
# WARNING:cassandra.cluster:Downgrading core protocol version from 65 to 5 for 4a1c36e1-80dc-415c-bbba-3d05e2197013-us-east1.db.astra.datastax.com:29042:3b8afe0a-9b27-48ef-af55-d95b0aef8e45. To avoid this, it is best practice to explicitly set Cluster(protocol_version) to the version supported by your cluster. http://datastax.github.io/python-driver/api/cassandra/cluster.html#cassandra.cluster.Cluster.protocol_version
# ERROR:cassandra.connection:Closing connection <LibevConnection(137198247292080) 4a1c36e1-80dc-415c-bbba-3d05e2197013-us-east1.db.astra.datastax.com:29042:3b8afe0a-9b27-48ef-af55-d95b0aef8e45> due to protocol error: Error from server: code=000a [Protocol error] message="Beta version of the protocol used (5/v5-beta), but USE_BETA flag is unset"
# WARNING:cassandra.cluster:Downgrading core protocol version from 5 to 4 for 4a1c36e1-80dc-415c-bbba-3d05e2197013-us-east1.db.astra.datastax.com:29042:3b8afe0a-9b27-48ef-af55-d95b0aef8e45. To avoid this, it is best practice to explicitly set Cluster(protocol_version) to the version supported by your cluster. http://datastax.github.io/python-driver/api/cassandra/cluster.html#cassandra.cluster.Cluster.protocol_version
# 4.0.11-09ec37c912ed

# %% [markdown]
# # Import

# %%
from langchain.llms import Cohere
from langchain.embeddings import CohereEmbeddings
from langchain.vectorstores.cassandra import Cassandra
from langchain.indexes import VectorstoreIndexCreator
from langchain.text_splitter import (
    CharacterTextSplitter,
    RecursiveCharacterTextSplitter,
)
from langchain.docstore.document import Document
from langchain.document_loaders import TextLoader, PyPDFLoader

# %%
os.environ['COHERE_API_KEY'] = COHERE_API_KEY

# %% [markdown]
# # Initialization

# %% [markdown]
# Now we set up a Cohere language model for text generation and a Cohere embeddings model for converting text into numerical vectors.

# %%
from langchain.llms import Cohere
from langchain.embeddings import CohereEmbeddings

llm = Cohere(model="command-r-plus", temperature=0)
cohere_embeddings = CohereEmbeddings()
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `Cohere` was deprecated in LangChain 0.1.14 and will be removed in 0.3.0. An updated version of the class exists in the langchain-cohere package and should be used instead. To use it run `pip install -U langchain-cohere` and import as `from langchain_cohere import Cohere`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `CohereEmbeddings` was deprecated in LangChain 0.0.30 and will be removed in 0.3.0. An updated version of the class exists in the langchain-cohere package and should be used instead. To use it run `pip install -U langchain-cohere` and import as `from langchain_cohere import CohereEmbeddings`.
#   warn_deprecated(

# %% [markdown]
# Here I am basically setting up a system to index and store vectorized text data in a Cassandra database using embeddings generated by Cohere. It splits the text into chunks of 400 characters with an overlap of 30 characters, converts these chunks into embeddings, and stores them in a specified table and keyspace in Cassandra. This allows for efficient querying and retrieval of relevant text data based on vector similarity.

# %%
table_name = 'pdf_q_n_a_table_1'
keyspace = "default_keyspace"

index_creator = VectorstoreIndexCreator(
    vectorstore_cls = Cassandra,
    embedding = cohere_embeddings,
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size = 400,
        chunk_overlap = 30,
    ),
    vectorstore_kwargs={
        'session': session,
        'keyspace': keyspace,
        'table_name': table_name,
    },
)

# %% [markdown]
# # Loading PDF

# %%
file_name = input("Enter the PDF file name: ")
loader = PyPDFLoader(file_name)
pages = loader.load_and_split()
# Out:
# Enter the PDF file name: test.pdf

# %%
len(pages)
# Out:
# 17

# %%
pages[1]
# Out:
# Document(metadata={'source': 'test.pdf', 'page': 1}, page_content='The EUROCALL Review,  Volume 25, No. 2, September 2017  \n \n 19 namely a research question, description of participants, data collection tools and \nanalysis. This is followe d by the presentation of the results of the study. The article \ncloses with discussion and conclusions.  \n2. Literature review  \n2.1. Autonomy in foreign/second language learning  \nThe concept of autonomy in second/foreign language learning and teaching has been \nthe focus of attention for many researchers and practitioners for more than three \ndecades. According to Benson (2001), the notion of autonomy was introduced and \npopularized in 1981 by Henri Holec in his seminal report for the Council of Europe \nentitled  Autonomy in Foreign Language Learning  in which the researcher defined \nautonomy in the context of language learning as “the ability to take charge of one’s own \nlearning” (Holec, 1981, p. 3). Holec’s idea of autonomy encompasses some components \nand capacities o n the part of language learners (e.g. self -directed learning). For some \nother authors autonomy also involves “a capacity – for detachment, critical reflection, \ndecision -making, and independent action” (Little, 1991, p. 4) and “the capacity to take \ncontrol of one’s own learning” (Benson, 2001, p. 46). As stated by Benson (2011, p. \n16), “autonomy is multidimensional and takes many different forms according to the \nperson, the setting, and multiple contextual and micro -contextual factors” and it is “a \nmulti-faceted concept that consists of several layers” (Reinders, 2011, p. 48) whose \nroots are based in political, societal and educational developments. In addition to this, \nwork on autonomy emphasizes social dimensions of learner autonomy in view of the \nfact that  “autonomous learners always do things for themselves, but they may or may \nnot do things on their own” (Little, 2009, p. 223) and that by means of social \ninteractions language learners “develop a capacity to analyze, reflect upon and \nsynthesize information  to create new perspectives” (Lee, 2011, p. 88). It should also be \nnoted that recent research shows that fostering autonomy is no longer predominantly a \nmatter of individualizing learning through out -of-class initiatives since the dominance of \nclassroom -based approaches (Benson, 2011). Finally, it has to be added that \nresearchers, in general, seem to be in agreement with the following claims suggested \nby Benson (2011): “(a) language learners naturally tend to take control of their \nlearning, (b) learners who  lack autonomy are capable of developing it, and (c) \nautonomous language learning is more effective than non -autonomous language \nlearning” (p. 16).  \nPerhaps in order to define the concept of autonomy in language learning it is necessary \nto understand who au tonomous learners are. As Littlewood (1996) claims, an \nautonomous learner is “one who has independent capacity to make and carry out \nchoices which govern his or her actions” (p. 428). The researcher argues that this \ncapacity depends on two major components  such as ability and willingness, and he \nclaims that the attributes can also be further subdivided. Thus, ability depends on \nhaving knowledge about the options from which one can choose and skills so as to \nchoose the most suitable alternatives. When it com es to willingness, this depends on \nhaving motivation and confidence in order to take responsibility for adequate choices. \nMoreover, Littlewood (1996) argues that if an individual is to be successful in being \nautonomous, all of these components have to be p resent all together.  \nAt the close of this section, a few words are in order on the notion of autonomous \nlanguage learning. An interesting description of the concept in question is offered by \nReinders (2011), who defines autonomous language learning as “an act of learning \nwhereby motivated learners consciously make  ...

# %% [markdown]
# # Load to Index

# %% [markdown]
# Here I will create an index for the documents loaded by the specified loader. This index can then be used for various purposes, such as searching for specific content within the documents.
#
# * pdf_index will be the created index that can be queried to retrieve information from the PDF documents loaded by the loader.

# %%
pdf_index = index_creator.from_loaders([loader])

# %% [markdown]
# Here I will retrieve all rows from the specified Cassandra table and prints some of the contents of each row, including the row_id, a truncated version of the embedding_vector, a truncated version of the body_blob, and the metadata_blob. This is useful for debugging or inspecting the contents of the table.

# %%
default_query = f'SELECT * FROM {keyspace}.{table_name}'

rows = session.execute(default_query)

for row_i, row in enumerate(rows):
    print(f'\nRow {row_i}:')
    print(f'row_id: {row.row_id}')
    print(f'embedding_vector: {str(row.vector)[:64]} ...')
    print(f'body_blob: {row.body_blob[:64]} ...')
    print(f'metadata_blob: {row.metadata_s}')

print('\n...')
# Out:
# Streaming output truncated to the last 5000 lines.
# embedding_vector: [-0.1748046875, 2.138671875, 1.8408203125, -3.240234375, 1.77636 ...
# body_blob: the
# r egular
# meetings
# pla y ed
# a
# crucial
# r ole
# in
# k eeping
# me
# al ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1568:
# row_id: f371b37262c7480fad153ac8366fcf29
# embedding_vector: [-1.85546875, 2.6015625, 1.7607421875, -1.4208984375, -0.1636962 ...
# body_blob: interest among researchers in recent years (Byrne & Diem, 2014). ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1569:
# row_id: a9595b3eab4347f486b81638f2b53c16
# embedding_vector: [-0.919921875, 2.09375, 0.2724609375, -0.70947265625, 1.52050781 ...
# body_blob: instance, the use of chunks of spare time for language practice, ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1570:
# row_id: a0ff1a4c1b394372b269e3ab86a95080
# embedding_vector: [-0.5400390625, 0.246337890625, 0.453857421875, -1.7216796875, 1 ...
# body_blob: since they were accessible to the researcher (Dörnyei, 2007, p.  ...
# metadata_blob: {'page': '10.0', 'source': 'temp.pdf'}
#
# Row 1571:
# row_id: 8c1334de66ee4b058de17ab5a7769ebb
# embedding_vector: [-0.86376953125, 1.373046875, 1.3349609375, 0.09173583984375, 1. ...
# body_blob: describe their learning experiences concerning the use of mobile ...
# metadata_blob: {'page': '3.0', 'source': 'test.pdf'}
#
# Row 1572:
# row_id: 2756458f7d164bc4ab3fe96c5fc1076b
# embedding_vector: [0.09259033203125, -0.1754150390625, 0.02508544921875, -0.082763 ...
# body_blob: and mobile apps. The most frequently used language tools were on ...
# metadata_blob: {'page': '5.0', 'source': 'temp.pdf'}
#
# Row 1573:
# row_id: 0f16eb63143d4b87930265f9ed1b11cf
# embedding_vector: [-0.264892578125, 1.3759765625, 3.263671875, -0.51220703125, 1.4 ...
# body_blob: learners' use of mobile devices for learning English is relative ...
# metadata_blob: {'page': '8.0', 'source': 'test.pdf'}
#
# Row 1574:
# row_id: 100904d69d8845519a9f9a54476d717b
# embedding_vector: [0.09259033203125, -0.1754150390625, 0.02508544921875, -0.082763 ...
# body_blob: and mobile apps. The most frequently used language tools were on ...
# metadata_blob: {'page': '5.0', 'source': 'test.pdf'}
#
# Row 1575:
# row_id: 387eea19d1a5413d95400abd2c55206f
# embedding_vector: [-0.3916015625, 1.4755859375, 1.3984375, -0.970703125, 1.7470703 ...
# body_blob: her individual needs and goals (Kukulska -Hulme, Traxler & Petti ...
# metadata_blob: {'page': '2.0', 'source': 'test.pdf'}
#
# Row 1576:
# row_id: c50d2ad3e5724d84911df4305319cd58
# embedding_vector: [-1.001953125, 0.99462890625, 0.37646484375, -0.307861328125, 1. ...
# body_blob: spelling and also listen to pronunciation (How about phonetic tr ...
# metadata_blob: {'page': '7.0', 'source': 'test.pdf'}
#
# Row 1577:
# row_id: 77a3dc5a493d44d1a2f87dd67bd2dc88
# embedding_vector: [0.329345703125, -0.3359375, 1.86328125, -1.7021484375, -1.42285 ...
# body_blob: principles.
# I’v e
# gained
# knowledge
# on
# eff ectiv ely
# using
# CRM
# an ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1578:
# row_id: 197d07c6037b45b6aa9d620df2dd43b8
# embedding_vector: [-1.486328125, 1.33203125, 1.525390625, -0.457275390625, -0.1866 ...
# body_blob:  Do you use your mobile device(s) more often in relation to for ...
# metadata_blob: {'page': '3.0', 'source': 'temp.pdf'}
#
# Row 1579:
# row_id: 7424094a5e0d4ad7b7918c4adc153c08
# embedding_vector: [-0.52392578125, 1.1865234375, 1.08203125, 0.38232421875, 0.6323 ...
# body_blob: claims that the attributes can also be further subdivided. Thus, ...
# metadata_blob: {'page': '1.0', 'source': 'test.pdf'}
#
# Row 1580:
# row_id: 73fec4b1f6874f67a9311cbf2e32eb1b
# embedding_vector: [-1.51171875, -1.4208984375, 1.1240234375, 0.77880859375, 1.5654 ...
# body_blob: by Benson (2011): “(a) language learners naturally tend to take  ...
# metadata_blob: {'page': '1.0', 'source': 'test.pdf'}
#
# Row 1581:
# row_id: 30527933c5a74bc6bd9cd65be7d3e24b
# embedding_vector: [-0.68017578125, -0.1566162109375, 1.8310546875, -0.297607421875 ...
# body_blob: English vocabulary is concerned, the subjects chose to practice  ...
# metadata_blob: {'page': '7.0', 'source': 'test.pdf'}
#
# Row 1582:
# row_id: 667e6311b18541298eabdb80c468664c
# embedding_vector: [-1.8662109375, -1.2919921875, 0.053070068359375, 0.693359375, 0 ...
# body_blob: to understand who au tonomous learners are. As Littlewood (1996) ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1583:
# row_id: f86bd84dd2394e06961a1315a6228fe7
# embedding_vector: [-1.0888671875, -0.047119140625, 0.045623779296875, -0.706054687 ...
# body_blob: situations present different demands. Reinders (2011) further ar ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1584:
# row_id: 3133af833a5c498cbfcffb295d326812
# embedding_vector: [0.490966796875, 1.412109375, 2.8359375, -0.46044921875, 1.32421 ...
# body_blob: devices could be altered if teachers took into account the benef ...
# metadata_blob: {'page': '8.0', 'source': 'test.pdf'}
#
# Row 1585:
# row_id: 30baa69ef813461bbbd5a2363450f5fb
# embedding_vector: [-0.64990234375, 1.4033203125, 1.970703125, -0.67919921875, 1.50 ...
# body_blob:  As far as learning English through your mobile device(s) is co ...
# metadata_blob: {'page': '4.0', 'source': 'temp.pdf'}
#
# Row 1586:
# row_id: d12c74fa5c47447387ff738109b8cc8f
# embedding_vector: [0.329345703125, -0.3359375, 1.86328125, -1.7021484375, -1.42285 ...
# body_blob: principles.
# I’v e
# gained
# knowledge
# on
# eff ectiv ely
# using
# CRM
# an ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1587:
# row_id: 339463e3e5264f0f804468cbfe5c2a29
# embedding_vector: [0.48583984375, -0.1300048828125, 1.1298828125, -0.47021484375,  ...
# body_blob: 3.80 years (minimum 2, maximum 6 years). 9 (45 %) and 11 (55%) o ...
# metadata_blob: {'page': '4.0', 'source': 'test.pdf'}
#
# Row 1588:
# row_id: 612e5002db9f4e17ace6e9af948c77e5
# embedding_vector: [0.329345703125, -0.3359375, 1.86328125, -1.7021484375, -1.42285 ...
# body_blob: principles.
# I’v e
# gained
# knowledge
# on
# eff ectiv ely
# using
# CRM
# an ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1589:
# row_id: c0c894e9114d4b5bb162454652fc3fcb
# embedding_vector: [-0.64990234375, 1.4033203125, 1.970703125, -0.67919921875, 1.50 ...
# body_blob:  As far as learning English through your mobile device(s) is co ...
# metadata_blob: {'page': '4.0', 'source': 'test.pdf'}
#
# Row 1590:
# row_id: 0a220e6896474078a63a738c88ec904b
# embedding_vector: [-0.05474853515625, 2.3125, 1.0771484375, -2.74609375, 0.2729492 ...
# body_blob: enhanced
# my
# skill
# set
# but
# also
# br oadened
# my
# understanding
# of
# cr ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1591:
# row_id: e981cac86f274ff9b354075df52928ef
# embedding_vector: [-1.486328125, 1.33203125, 1.525390625, -0.457275390625, -0.1866 ...
# body_blob:  Do you use your mobile device(s) more often in relation to for ...
# metadata_blob: {'page': '3.0', 'source': 'test.pdf'}
#
# Row 1592:
# row_id: 55ccf997300c4500bd24e72d1bb90524
# embedding_vector: [0.378662109375, 0.6630859375, 2.890625, -0.86328125, 0.68603515 ...
# body_blob: should prepare them for effective usage of such devices for this ...
# metadata_blob: {'page': '0.0', 'source': 'test.pdf'}
#
# Row 1593:
# row_id: 708445dec9364769b97d2ae2419fc8fb
# embedding_vector: [-0.246337890625, 0.325439453125, 1.21484375, -0.376953125, 1.72 ...
# body_blob: individuals need to be increasingly adept at critical adaptive l ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1594:
# row_id: acb5086c801741f7b2b21bb88260a73f
# embedding_vector: [0.1937255859375, 1.42578125, 0.55419921875, -2.31640625, 0.2578 ...
# body_blob: interviewer provides guidelines and direction (hence the ‘ -stru ...
# metadata_blob: {'page': '3.0', 'source': 'temp.pdf'}
#
# Row 1595:
# row_id: 481a548137dc4f4dbac417f250081069
# embedding_vector: [-0.806640625, 1.5869140625, 1.54296875, -0.59375, -0.64453125,  ...
# body_blob: number of participants reduces the generalizability of the resul ...
# metadata_blob: {'page': '8.0', 'source': 'temp.pdf'}
#
# Row 1596:
# row_id: d3ac5fb520fa4b2b83d7a6662e7899a9
# embedding_vector: [-0.6591796875, 0.931640625, 0.91796875, 0.2181396484375, 2.7929 ...
# body_blob: 4.5. La nguage practiced
# When asked to indicate the most frequ ...
# metadata_blob: {'page': '7.0', 'source': 'test.pdf'}
#
# Row 1597:
# row_id: 0bff87afaa55423a9822a0d1644f6efb
# embedding_vector: [-0.230224609375, -0.32763671875, 4.421875, -2.744140625, 1.6044 ...
# body_blob: thus it is difficult to achieve and is not invariably permanent  ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1598:
# row_id: 490de65e9b77424daa67f68172d5bf8a
# embedding_vector: [-0.806640625, 1.5869140625, 1.54296875, -0.59375, -0.64453125,  ...
# body_blob: number of participants reduces the generalizability of the resul ...
# metadata_blob: {'page': '8.0', 'source': 'temp.pdf'}
#
# Row 1599:
# row_id: 8c5c0988fe59443f967c07555a7c2c0e
# embedding_vector: [0.1529541015625, 0.412841796875, 2.478515625, -0.366455078125,  ...
# body_blob: started to be influenced by technology in the mid -1990s as a re ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1600:
# row_id: d76dbeaa0aff486fbe988bc4b6081990
# embedding_vector: [-0.01593017578125, 0.162841796875, 0.64453125, -2.044921875, 1. ...
# body_blob: computer word processor program  Microsoft Word 2016 . Then the  ...
# metadata_blob: {'page': '4.0', 'source': 'test.pdf'}
#
# Row 1601:
# row_id: b6e72331f9ab4a67a225fec2e789eec7
# embedding_vector: [-0.2349853515625, 1.93359375, 2.2109375, -0.2449951171875, 1.90 ...
# body_blob: Despite this positive view o f MobDs reported by the study parti ...
# metadata_blob: {'page': '8.0', 'source': 'test.pdf'}
#
# Row 1602:
# row_id: a40a2cefc6df4333be4ea075a159b414
# embedding_vector: [1.19140625, 0.775390625, 1.328125, -2.37890625, 1.6904296875, - ...
# body_blob: then
# testing
# e v er ything.
# Also,
# collecting
# r eliable
# data
# was
#  ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1603:
# row_id: 36608bb5223843758ca6fb7268a9306b
# embedding_vector: [0.8125, 1.3076171875, 1.384765625, -2.669921875, -1.2333984375, ...
# body_blob: of
# the
# landing
# page
# in
# r elation
# t o
# CRM
# and
# pa yment
# integr ati ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1604:
# row_id: 66d94e3e4ce44e8a8e2ed6403aedab21
# embedding_vector: [-1.51171875, -1.4208984375, 1.1240234375, 0.77880859375, 1.5654 ...
# body_blob: by Benson (2011): “(a) language learners naturally tend to take  ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1605:
# row_id: dc7c2e1b5f5f4738b7e2629670c93ff7
# embedding_vector: [0.72509765625, 1.96875, 1.958984375, -2.361328125, 1.2333984375 ...
# body_blob: 2.
# Accomplishments
# Thr oughout
# my
# internship,
# I
# dedicated
# myself ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1606:
# row_id: 8678a608727b45e1b7dcb37a854a7684
# embedding_vector: [0.66357421875, 1.1142578125, 0.6630859375, -2.09375, 0.39379882 ...
# body_blob: Performance
# Appraisal
# Self-evaluation
# Template
# Name:
# Sumeet
# Prus ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1607:
# row_id: 69a5e7360be34426915d02d3657d4b9f
# embedding_vector: [0.1937255859375, 1.42578125, 0.55419921875, -2.31640625, 0.2578 ...
# body_blob: interviewer provides guidelines and direction (hence the ‘ -stru ...
# metadata_blob: {'page': '3.0', 'source': 'temp.pdf'}
#
# Row 1608:
# row_id: ffba74e7922f4020bb4442078353b159
# embedding_vector: [-0.376220703125, 1.9228515625, 2.638671875, -0.93505859375, 0.7 ...
# body_blob: qualitative and q uantitative analysis. The results of the study ...
# metadata_blob: {'page': '0.0', 'source': 'test.pdf'}
#
# Row 1609:
# row_id: 2f20d42ba49f4aa88caad5c4ab132117
# embedding_vector: [-1.1435546875, 0.432373046875, 1.390625, -0.352783203125, 2.046 ...
# body_blob: a smartphone or a tablet allows  some learners  devote more time ...
# metadata_blob: {'page': '7.0', 'source': 'test.pdf'}
#
# Row 1610:
# row_id: c9917d2476024a89be79f1b0eb88d408
# embedding_vector: [0.69580078125, 0.70751953125, 1.5556640625, -1.212890625, 0.642 ...
# body_blob: a
# landing
# page
# tr anslated
# int o
# F r ench.
# 19.
# Re viewed
# US
# Inte ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1611:
# row_id: 4f76b1226b404e1cad7500adf877c33c
# embedding_vector: [-0.1748046875, 2.138671875, 1.8408203125, -3.240234375, 1.77636 ...
# body_blob: the
# r egular
# meetings
# pla y ed
# a
# crucial
# r ole
# in
# k eeping
# me
# al ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1612:
# row_id: d373f38ee0d440cfb8f8739421cb27fd
# embedding_vector: [1.2236328125, 0.2359619140625, 0.1490478515625, -0.3076171875,  ...
# body_blob: in
# the
# USA,
# EU,
# and
# A ustr alia.
# 2.
# Inv estigated
# the
# eff ectiv  ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1613:
# row_id: 284d3e1b531a4fdd81e26ded7a2ea1bb
# embedding_vector: [0.490966796875, 1.412109375, 2.8359375, -0.46044921875, 1.32421 ...
# body_blob: devices could be altered if teachers took into account the benef ...
# metadata_blob: {'page': '8.0', 'source': 'temp.pdf'}
#
# Row 1614:
# row_id: bbfdc40c7a504dac8ae6ff5348935696
# embedding_vector: [-0.93115234375, 1.16796875, 0.7587890625, -0.9423828125, -0.817 ...
# body_blob: of the students’ responses by the present author. ...
# metadata_blob: {'page': '10.0', 'source': 'temp.pdf'}
#
# Row 1615:
# row_id: 69e82755a0394c3a90a9dcb64f82cb21
# embedding_vector: [-0.2349853515625, 1.93359375, 2.2109375, -0.2449951171875, 1.90 ...
# body_blob: Despite this positive view o f MobDs reported by the study parti ...
# metadata_blob: {'page': '8.0', 'source': 'temp.pdf'}
#
# Row 1616:
# row_id: 3bea496c6262434a90f94b5b1155c860
# embedding_vector: [-0.716796875, 0.339599609375, 0.99560546875, -1.068359375, 0.02 ...
# body_blob: noted that recent research shows that fostering autonomy is no l ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1617:
# row_id: 475f95460366423581f41c94b725ad34
# embedding_vector: [0.1529541015625, 0.412841796875, 2.478515625, -0.366455078125,  ...
# body_blob: started to be influenced by technology in the mid -1990s as a re ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1618:
# row_id: 26406de3648f47699b078a8144c9f3b0
# embedding_vector: [0.71826171875, 0.30810546875, 0.63037109375, -1.9765625, -0.252 ...
# body_blob: (five females and one male) in the third year and five (all fema ...
# metadata_blob: {'page': '3.0', 'source': 'temp.pdf'}
#
# Row 1619:
# row_id: e521140c7ffb4d05951faf546fc47b4e
# embedding_vector: [-1.0283203125, 1.1552734375, 0.771484375, -0.9521484375, 0.2286 ...
# body_blob: Technology (LLT)  concerned language learners engagement with te ...
# metadata_blob: {'page': '3.0', 'source': 'temp.pdf'}
#
# Row 1620:
# row_id: 41692938654e4c12a59c075f94b1021d
# embedding_vector: [0.8125, 1.3076171875, 1.384765625, -2.669921875, -1.2333984375, ...
# body_blob: of
# the
# landing
# page
# in
# r elation
# t o
# CRM
# and
# pa yment
# integr ati ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1621:
# row_id: 2fdbc08f7ed5411a9a74d9a6f80eef97
# embedding_vector: [-0.64990234375, 1.4033203125, 1.970703125, -0.67919921875, 1.50 ...
# body_blob:  As far as learning English through your mobile device(s) is co ...
# metadata_blob: {'page': '4.0', 'source': 'temp.pdf'}
#
# Row 1622:
# row_id: 5d55c3c73557428abf91bb27ab5fe4ee
# embedding_vector: [-1.0888671875, -0.047119140625, 0.045623779296875, -0.706054687 ...
# body_blob: situations present different demands. Reinders (2011) further ar ...
# metadata_blob: {'page': '1.0', 'source': 'test.pdf'}
#
# Row 1623:
# row_id: 1b0ae04a720d403a997abd62a8ff3613
# embedding_vector: [1.5361328125, 1.30859375, 1.6884765625, -1.8818359375, 1.003906 ...
# body_blob: ha v e
# enhanced
# my
# skills
# in
# designing
# landing
# pages
# and
# incorpo ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1624:
# row_id: c578e818efb54fdbaef5c162a7996237
# embedding_vector: [0.2022705078125, 1.0068359375, 1.9580078125, -1.1494140625, -0. ...
# body_blob: Finally, it should be noted that 5 (25%) interviewees were not a ...
# metadata_blob: {'page': '8.0', 'source': 'test.pdf'}
#
# Row 1625:
# row_id: dcd2ecba550d4d26b283286d3b4e9609
# embedding_vector: [0.2509765625, 1.0947265625, 2.337890625, -0.19921875, 1.6240234 ...
# body_blob: frequently with time. Finally, more than half of the students (5 ...
# metadata_blob: {'page': '4.0', 'source': 'test.pdf'}
#
# Row 1626:
# row_id: ffcc7193e95749eeb51f4a39b115a203
# embedding_vector: [1.41796875, -0.2117919921875, 1.7587890625, -2.791015625, -0.16 ...
# body_blob: its
# r each.
# 5.
# Successfully
# cr eated
# a
# F r ench
# mark eting
# campa ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1627:
# row_id: 02d2583c60f0417793237613582bf935
# embedding_vector: [0.2039794921875, 1.0068359375, 1.9560546875, -1.146484375, -0.0 ...
# body_blob: Finally, it should be noted that 5 (25%) interviewees were not a ...
# metadata_blob: {'page': '8.0', 'source': 'temp.pdf'}
#
# Row 1628:
# row_id: 82b51bb27c4a4fedb9decf85d4aef4bf
# embedding_vector: [1.2236328125, 0.2359619140625, 0.1490478515625, -0.3076171875,  ...
# body_blob: in
# the
# USA,
# EU,
# and
# A ustr alia.
# 2.
# Inv estigated
# the
# eff ectiv  ...
# metadata_blob: {'page': '0.0', 'source': 'Sumeet.pdf'}
#
# Row 1629:
# row_id: 40b6e8592fbf43fc852038ba5323e5b8
# embedding_vector: [1.1337890625, -0.88671875, 2.84375, -2.607421875, 0.21374511718 ...
# body_blob: Note: Helped in  design ing the shirt and the id’s of the core t ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1630:
# row_id: 4ed7d9666771483cae3f0107bd4f590a
# embedding_vector: [0.71630859375, 0.80419921875, 1.6318359375, -2.625, -0.43920898 ...
# body_blob: eﬃciently ,
# balancing
# both
# my
# academic
# r esponsibilities
# with
# me ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1631:
# row_id: ee5804fd929649f897dcaafa8bb453fe
# embedding_vector: [0.66357421875, 1.1142578125, 0.6630859375, -2.09375, 0.39379882 ...
# body_blob: Performance
# Appraisal
# Self-evaluation
# Template
# Name:
# Sumeet
# Prus ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1632:
# row_id: 971dadbfc9f044b790e6f9c15629269b
# embedding_vector: [0.48583984375, -0.1300048828125, 1.1298828125, -0.47021484375,  ...
# body_blob: 3.80 years (minimum 2, maximum 6 years). 9 (45 %) and 11 (55%) o ...
# metadata_blob: {'page': '4.0', 'source': 'temp.pdf'}
#
# Row 1633:
# row_id: c7a6ec9ff6a14e7eb351a71646e5074c
# embedding_vector: [-0.6044921875, 0.475341796875, 3.353515625, 0.447509765625, 1.0 ...
# body_blob: student to learn more (S6:  I’m more willing to use my smartphon ...
# metadata_blob: {'page': '7.0', 'source': 'temp.pdf'}
#
# Row 1634:
# row_id: f92b3a41021a4574916701f8d1365b46
# embedding_vector: [0.66357421875, 1.1142578125, 0.6630859375, -2.09375, 0.39379882 ...
# body_blob: Performance
# Appraisal
# Self-evaluation
# Template
# Name:
# Sumeet
# Prus ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1635:
# row_id: 33ef1ceabd284ccf9686c50975204f0e
# embedding_vector: [-1.8505859375, -0.1063232421875, 1.1953125, 0.0750732421875, 0. ...
# body_blob: study) that meet their needs and goals (e.g. the development of  ...
# metadata_blob: {'page': '3.0', 'source': 'temp.pdf'}
#
# Row 1636:
# row_id: 9200b89a161840d199d88caf9653ea30
# embedding_vector: [0.71875, 0.80419921875, 1.62890625, -2.626953125, -0.4375, -1.7 ...
# body_blob: eﬃciently ,
# balancing
# both
# my
# academic
# r esponsibilities
# with
# me ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1637:
# row_id: 6961cf68790b466592105314ff42da5f
# embedding_vector: [0.8125, 1.3076171875, 1.384765625, -2.669921875, -1.2333984375, ...
# body_blob: of
# the
# landing
# page
# in
# r elation
# t o
# CRM
# and
# pa yment
# integr ati ...
# metadata_blob: {'page': '0.0', 'source': 'Sumeet.pdf'}
#
# Row 1638:
# row_id: 50256220367a404ead4049f3426f2878
# embedding_vector: [0.378662109375, 0.6630859375, 2.890625, -0.86328125, 0.68603515 ...
# body_blob: should prepare them for effective usage of such devices for this ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1639:
# row_id: 388d2e5fc6c84a0991c5aa8621e2c2cf
# embedding_vector: [-0.27099609375, 2.40234375, 0.2364501953125, -0.63671875, 2.302 ...
# body_blob: stressed by many of the interviewees, learning English vocabular ...
# metadata_blob: {'page': '7.0', 'source': 'test.pdf'}
#
# Row 1640:
# row_id: 047a914ee76d4e27be9989332ca1ce5a
# embedding_vector: [-1.1171875, 1.833984375, 0.2122802734375, -0.87744140625, 1.966 ...
# body_blob: 435.
# Miangah, T.M. & Nezarat, A. (2012). Mobile -assisted langu ...
# metadata_blob: {'page': '10.0', 'source': 'test.pdf'}
#
# Row 1641:
# row_id: d4c6d66a159d43b6b3db955fd6dc7a60
# embedding_vector: [-0.37744140625, 0.931640625, 1.0146484375, -0.5029296875, 1.374 ...
# body_blob: do distance learners use mobile devices for language learning?   ...
# metadata_blob: {'page': '9.0', 'source': 'temp.pdf'}
#
# Row 1642:
# row_id: 75cb73d254ad4b71b1b51ad0e2a9c4ef
# embedding_vector: [-0.3916015625, 1.4755859375, 1.3984375, -0.970703125, 1.7470703 ...
# body_blob: her individual needs and goals (Kukulska -Hulme, Traxler & Petti ...
# metadata_blob: {'page': '2.0', 'source': 'test.pdf'}
#
# Row 1643:
# row_id: fa4c6abdcb2e4da2994cb2f632047fd6
# embedding_vector: [-0.1748046875, 2.138671875, 1.8408203125, -3.240234375, 1.77636 ...
# body_blob: the
# r egular
# meetings
# pla y ed
# a
# crucial
# r ole
# in
# k eeping
# me
# al ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1644:
# row_id: 24d1858fb99a4b6998fdd141e9b14efa
# embedding_vector: [-0.32568359375, 1.25390625, 1.26171875, -0.62060546875, 1.46777 ...
# body_blob: Byrne, J. & Diem, R. (2014). Profiling mobile English language l ...
# metadata_blob: {'page': '9.0', 'source': 'temp.pdf'}
#
# Row 1645:
# row_id: 9680ed775dbb447ea8930cd3e530aa4a
# embedding_vector: [0.24462890625, 0.96044921875, 1.2158203125, -0.6748046875, 0.66 ...
# body_blob: learners who do not have direct access to the target language. T ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1646:
# row_id: 30c5222abe1249199f1511d92a1dcc5d
# embedding_vector: [-1.486328125, 1.33203125, 1.525390625, -0.457275390625, -0.1866 ...
# body_blob:  Do you use your mobile device(s) more often in relation to for ...
# metadata_blob: {'page': '3.0', 'source': 'test.pdf'}
#
# Row 1647:
# row_id: 10c0a5aaece14c66b65b82f33cbf44df
# embedding_vector: [-0.05474853515625, 2.306640625, 1.0771484375, -2.748046875, 0.2 ...
# body_blob: enhanced
# my
# skill
# set
# but
# also
# br oadened
# my
# understanding
# of
# cr ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1648:
# row_id: f1d94813fe1a46b58059177e15db45a3
# embedding_vector: [-0.1748046875, 2.138671875, 1.8408203125, -3.240234375, 1.77636 ...
# body_blob: the
# r egular
# meetings
# pla y ed
# a
# crucial
# r ole
# in
# k eeping
# me
# al ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1649:
# row_id: 5015407e265140679847075c289e9652
# embedding_vector: [-0.27099609375, 2.40234375, 0.2364501953125, -0.63671875, 2.302 ...
# body_blob: stressed by many of the interviewees, learning English vocabular ...
# metadata_blob: {'page': '7.0', 'source': 'temp.pdf'}
#
# Row 1650:
# row_id: 07d4b4be68054816bc433e7e18c27a04
# embedding_vector: [-0.6044921875, 0.475341796875, 3.353515625, 0.447509765625, 1.0 ...
# body_blob: student to learn more (S6:  I’m more willing to use my smartphon ...
# metadata_blob: {'page': '7.0', 'source': 'test.pdf'}
#
# Row 1651:
# row_id: de5f6ae327eb4479bb84c6249f5c2f01
# embedding_vector: [-0.87548828125, 1.5126953125, 1.658203125, 0.0268402099609375,  ...
# body_blob:  When did you start using your mobile device(s) for learning En ...
# metadata_blob: {'page': '3.0', 'source': 'temp.pdf'}
#
# Row 1652:
# row_id: a3e0f7c555d644d0a03522d2c1ed3e20
# embedding_vector: [-0.1748046875, 2.138671875, 1.8408203125, -3.240234375, 1.77636 ...
# body_blob: the
# r egular
# meetings
# pla y ed
# a
# crucial
# r ole
# in
# k eeping
# me
# al ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1653:
# row_id: 5d206508b440494c940d58a5409e808c
# embedding_vector: [-1.3623046875, 1.2744140625, 2.958984375, 0.470703125, 0.725097 ...
# body_blob: mobile devices such as smartphones and tablet computers , are ub ...
# metadata_blob: {'page': '3.0', 'source': 'temp.pdf'}
#
# Row 1654:
# row_id: 74a5a8aa51074d89b837b5ecc0ca740c
# embedding_vector: [0.62744140625, -0.240966796875, 2.52734375, -2.8046875, 0.79638 ...
# body_blob: Event Name: Abdul Bari( Algorithmic Brilliance: Expert insights  ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1655:
# row_id: 21a6bf9a742f4df4ad0b0c44bd6077f5
# embedding_vector: [-0.3916015625, 1.4755859375, 1.3984375, -0.970703125, 1.7470703 ...
# body_blob: her individual needs and goals (Kukulska -Hulme, Traxler & Petti ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1656:
# row_id: a69bb64fa4fa49a0a2916cb3d7a3f31f
# embedding_vector: [1.7265625, -1.2158203125, 0.51806640625, -1.958984375, 0.458496 ...
# body_blob: work
# on
# ﬁnalizing
# the
# design
# for
# the
# mark eting
# campaign.
# 8.
# Com ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1657:
# row_id: bb7e76503f4442a8ba53adde48d73a0f
# embedding_vector: [-0.8642578125, -1.1162109375, 0.28466796875, -0.56005859375, 1. ...
# body_blob: The EUROCALL Review,  Volume 25, No. 2, September 2017
#
#  20 2 ...
# metadata_blob: {'page': '2.0', 'source': 'test.pdf'}
#
# Row 1658:
# row_id: cc16b0236be145d99131d4859eac8b10
# embedding_vector: [0.970703125, 1.830078125, 1.5849609375, -1.544921875, 0.6611328 ...
# body_blob: The data were gathered by means of a semi -structured interview. ...
# metadata_blob: {'page': '3.0', 'source': 'temp.pdf'}
#
# Row 1659:
# row_id: babaf8e15a464976b93baad52b609db0
# embedding_vector: [1.58203125, -0.06671142578125, 0.900390625, -0.38623046875, 0.0 ...
# body_blob: S6 male smartphone  2 years  experienced
# S7 female  smartphone ...
# metadata_blob: {'page': '4.0', 'source': 'temp.pdf'}
#
# Row 1660:
# row_id: 7b87a6a3316242e986ad93d8964736a1
# embedding_vector: [-0.919921875, 2.09375, 0.2724609375, -0.70947265625, 1.52050781 ...
# body_blob: instance, the use of chunks of spare time for language practice, ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1661:
# row_id: 0d80316e41cf4c57bcea736ebb5acb37
# embedding_vector: [1.41796875, -0.2117919921875, 1.7587890625, -2.791015625, -0.16 ...
# body_blob: its
# r each.
# 5.
# Successfully
# cr eated
# a
# F r ench
# mark eting
# campa ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1662:
# row_id: f4e34dd8d9f343c8978dd08d19c8ac7c
# embedding_vector: [0.75244140625, 0.6552734375, 1.9267578125, 0.64013671875, 2.347 ...
# body_blob: learning new vocabulary, preparing multimedia presentations and  ...
# metadata_blob: {'page': '6.0', 'source': 'temp.pdf'}
#
# Row 1663:
# row_id: 1326ee1693f14050aa86fc1e33f7daea
# embedding_vector: [0.50830078125, 1.4677734375, 2.650390625, 0.012603759765625, 0. ...
# body_blob: them with t he intention of learning English for years. Taking a ...
# metadata_blob: {'page': '8.0', 'source': 'test.pdf'}
#
# Row 1664:
# row_id: c1d925c8cbf84474817f6f8e6c474a18
# embedding_vector: [-1.486328125, 1.33203125, 1.525390625, -0.457275390625, -0.1866 ...
# body_blob:  Do you use your mobile device(s) more often in relation to for ...
# metadata_blob: {'page': '3.0', 'source': 'test.pdf'}
#
# Row 1665:
# row_id: 161fa6d716b64c5e9e8513a19c8c9dbf
# embedding_vector: [-0.8720703125, 0.5478515625, 0.8408203125, -0.61083984375, 3.48 ...
# body_blob: S3: (…) as for vocabulary I guess it’s much faster to search for ...
# metadata_blob: {'page': '7.0', 'source': 'temp.pdf'}
#
# Row 1666:
# row_id: 12d5de21ebcd48b08b76533c1b8903b4
# embedding_vector: [-2.0546875, 0.1812744140625, 1.609375, -1.0634765625, 1.4355468 ...
# body_blob: S5: I use apps for “index cards”, dictionaries and a variety of  ...
# metadata_blob: {'page': '6.0', 'source': 'test.pdf'}
#
# Row 1667:
# row_id: 4478395d717b47698262698131096015
# embedding_vector: [-0.56103515625, -0.5302734375, 2.6875, -0.0032672882080078125,  ...
# body_blob: they can be defined as “any device that is small, autonomous and ...
# metadata_blob: {'page': '2.0', 'source': 'test.pdf'}
#
# Row 1668:
# row_id: cd09e698ef544342a299f01385598bb0
# embedding_vector: [-1.248046875, 0.0299835205078125, 1.7939453125, -0.98388671875, ...
# body_blob: time, six (30%) in the classroom a nd one student said he had us ...
# metadata_blob: {'page': '6.0', 'source': 'temp.pdf'}
#
# Row 1669:
# row_id: ef0232365030482d8d73d591eca52ab3
# embedding_vector: [1.1337890625, -0.88671875, 2.84375, -2.607421875, 0.21374511718 ...
# body_blob: Note: Helped in  design ing the shirt and the id’s of the core t ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1670:
# row_id: 37c7bab21e3646dbb788ed27a282a78f
# embedding_vector: [0.60498046875, 0.1846923828125, 0.7880859375, -0.8251953125, -0 ...
# body_blob: The EUROCALL Review,  Volume 25, No. 2, September 2017
#
#  23 S ...
# metadata_blob: {'page': '5.0', 'source': 'temp.pdf'}
#
# Row 1671:
# row_id: e82a58aac44e4161b0f21f1122521296
# embedding_vector: [-0.27099609375, 2.40234375, 0.2364501953125, -0.63671875, 2.302 ...
# body_blob: stressed by many of the interviewees, learning English vocabular ...
# metadata_blob: {'page': '7.0', 'source': 'test.pdf'}
#
# Row 1672:
# row_id: afed39a8501a4bb780e0bacd3074479e
# embedding_vector: [-0.56103515625, -0.5302734375, 2.6875, -0.0032672882080078125,  ...
# body_blob: they can be defined as “any device that is small, autonomous and ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1673:
# row_id: 3393ff4a4c824aa2937b9f3189949f77
# embedding_vector: [-0.39697265625, 2.072265625, 1.6376953125, -0.66943359375, 1.88 ...
# body_blob: distance language learning (e.g. Demouy, Jones, Kan, Kukulska -H ...
# metadata_blob: {'page': '2.0', 'source': 'test.pdf'}
#
# Row 1674:
# row_id: 8d31464cd1d84291bb9fb7eddd6af946
# embedding_vector: [0.329345703125, -0.3359375, 1.86328125, -1.7021484375, -1.42285 ...
# body_blob: principles.
# I’v e
# gained
# knowledge
# on
# eff ectiv ely
# using
# CRM
# an ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1675:
# row_id: 6642634fc495416490463253755f32a8
# embedding_vector: [1.5361328125, 1.30859375, 1.6884765625, -1.8818359375, 1.003906 ...
# body_blob: ha v e
# enhanced
# my
# skills
# in
# designing
# landing
# pages
# and
# incorpo ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1676:
# row_id: d356a0d3b64b4e7d84faa94503eee6ac
# embedding_vector: [-0.6044921875, 0.475341796875, 3.353515625, 0.447509765625, 1.0 ...
# body_blob: student to learn more (S6:  I’m more willing to use my smartphon ...
# metadata_blob: {'page': '7.0', 'source': 'test.pdf'}
#
# Row 1677:
# row_id: 8184eb6dc185439687d7c644ec58400c
# embedding_vector: [-0.430908203125, 0.68115234375, 2.078125, -0.716796875, 1.12695 ...
# body_blob: through study abroad.  Language Learning & Technology , 5, 87-10 ...
# metadata_blob: {'page': '9.0', 'source': 'test.pdf'}
#
# Row 1678:
# row_id: 218126f4abd54f78a4c722bc847daee2
# embedding_vector: [-0.56689453125, 1.400390625, 1.5859375, -0.728515625, 1.8134765 ...
# body_blob: Oz, H. (2015). An investigation of preservice English teachers’  ...
# metadata_blob: {'page': '10.0', 'source': 'temp.pdf'}
#
# Row 1679:
# row_id: 1f801d6737db4a778f243dea42272d13
# embedding_vector: [-0.058990478515625, 0.2159423828125, -0.7578125, 0.94384765625, ...
# body_blob: person, the setting, and multiple contextual and micro -contextu ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1680:
# row_id: 30ab896e8efe43038376b0bce2ad36e8
# embedding_vector: [0.69287109375, 0.46630859375, 3.03515625, -2.044921875, 1.15527 ...
# body_blob: brainstorming event planning , helped in publicizing the event   ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1681:
# row_id: 74dee93bc8ad405d8903d1eaabaaf95f
# embedding_vector: [-1.4951171875, -0.322998046875, -0.89697265625, -1.529296875, 0 ...
# body_blob: The EUROCALL Review,  Volume 25, No. 2, September 2017
#
#  21 3 ...
# metadata_blob: {'page': '3.0', 'source': 'temp.pdf'}
#
# Row 1682:
# row_id: 1a274fb7435941308cd412e99b4d65cc
# embedding_vector: [-0.82861328125, -0.11712646484375, 3.302734375, -0.7177734375,  ...
# body_blob: useful addition to formal and informal language learning .
# Acco ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1683:
# row_id: 5ce2a933caed498b8cbfcce2ca47ade9
# embedding_vector: [-2.0078125, -0.1561279296875, 0.9921875, -0.72705078125, 1.1162 ...
# body_blob: The EUROCALL Review,  Volume 25, No. 2, September 2017
#
#  24 E ...
# metadata_blob: {'page': '6.0', 'source': 'test.pdf'}
#
# Row 1684:
# row_id: 333f491e18ba49328e010152299d35e0
# embedding_vector: [-0.88427734375, 1.3828125, 1.677734375, -1.7470703125, 2.621093 ...
# body_blob: we come and where to next?  Language Learning & Technology , 20( ...
# metadata_blob: {'page': '10.0', 'source': 'temp.pdf'}
#
# Row 1685:
# row_id: 4978559ee817429a941b95cf0e50c83d
# embedding_vector: [0.421630859375, 0.07373046875, 2.158203125, -1.236328125, 1.989 ...
# body_blob: by offering or designing tasks devoted to practicing a variety o ...
# metadata_blob: {'page': '8.0', 'source': 'temp.pdf'}
#
# Row 1686:
# row_id: 83d79760b90142cca9cad38b3bb3b7c8
# embedding_vector: [-1.90234375, 1.169921875, 1.6796875, 0.59130859375, 0.788085937 ...
# body_blob: English study and they were asked for permiss ion to be digitall ...
# metadata_blob: {'page': '3.0', 'source': 'temp.pdf'}
#
# Row 1687:
# row_id: 16eee5a8cc5347ef911c1ea1e7081039
# embedding_vector: [0.152099609375, 0.650390625, 1.623046875, -1.048828125, 0.76757 ...
# body_blob: Taking into consideration the above -mentioned issues, the study ...
# metadata_blob: {'page': '0.0', 'source': 'test.pdf'}
#
# Row 1688:
# row_id: 6a532a10327344d4b9238b13f1699032
# embedding_vector: [-1.248046875, 0.0299835205078125, 1.7939453125, -0.98388671875, ...
# body_blob: time, six (30%) in the classroom a nd one student said he had us ...
# metadata_blob: {'page': '6.0', 'source': 'test.pdf'}
#
# Row 1689:
# row_id: e2d2bf7fea884551a236a1817b5cb273
# embedding_vector: [0.28515625, -0.70703125, -0.55126953125, -2.1015625, 2.93164062 ...
# body_blob: can store them there (...) this also gives me easier access to t ...
# metadata_blob: {'page': '5.0', 'source': 'temp.pdf'}
#
# Row 1690:
# row_id: d8547d65033245baa7b49a0e2ab15ef6
# embedding_vector: [-1.330078125, 1.4677734375, 0.232666015625, -0.038543701171875, ...
# body_blob: Jones, A. (2015). Mobile informal language learning: Exploring W ...
# metadata_blob: {'page': '9.0', 'source': 'temp.pdf'}
#
# Row 1691:
# row_id: 45984c87bb9f4f6d97efbc72f5f2e8ec
# embedding_vector: [0.09423828125, 0.1478271484375, 1.6923828125, -1.0107421875, 1. ...
# body_blob: The EUROCALL Review,  Volume 25, No. 2, September 2017
#
#  18 R ...
# metadata_blob: {'page': '0.0', 'source': 'test.pdf'}
#
# Row 1692:
# row_id: 42640ab27fed496a83e9e494b366a564
# embedding_vector: [1.2509765625, 1.396484375, 0.85546875, 0.060455322265625, 1.513 ...
# body_blob: offered guidelines related to the implementation of mobile learn ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1693:
# row_id: 2a9e1e61d6fa4a6bb4476d3ebb4c10fa
# embedding_vector: [-0.6591796875, 0.931640625, 0.91796875, 0.2181396484375, 2.7929 ...
# body_blob: 4.5. La nguage practiced
# When asked to indicate the most frequ ...
# metadata_blob: {'page': '7.0', 'source': 'temp.pdf'}
#
# Row 1694:
# row_id: 7ee387d2dd624fc0a8c9754db9d00e39
# embedding_vector: [0.05316162109375, 1.109375, -0.485595703125, -1.0009765625, 0.8 ...
# body_blob: training not  only in the area of technology -mediated language  ...
# metadata_blob: {'page': '8.0', 'source': 'temp.pdf'}
#
# Row 1695:
# row_id: de80415ee91242ff840a03b4caf2eda4
# embedding_vector: [1.2509765625, 1.396484375, 0.85546875, 0.060455322265625, 1.513 ...
# body_blob: offered guidelines related to the implementation of mobile learn ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1696:
# row_id: 7ebe663b4607486a8cba2a67f48ac306
# embedding_vector: [-1.974609375, 0.8232421875, 0.6640625, -1.001953125, 1.17675781 ...
# body_blob: S19: Yes, I use my smartphone and tablet for out -of-class learn ...
# metadata_blob: {'page': '6.0', 'source': 'test.pdf'}
#
# Row 1697:
# row_id: 3e9c84ca348e48afba8626bf0930f12d
# embedding_vector: [1.5361328125, 1.30859375, 1.6884765625, -1.8818359375, 1.003906 ...
# body_blob: ha v e
# enhanced
# my
# skills
# in
# designing
# landing
# pages
# and
# incorpo ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1698:
# row_id: e3ca36eeac3647d8a5d3e9b23474c1c6
# embedding_vector: [-1.1416015625, -1.6435546875, 0.58984375, -1.22265625, 1.076171 ...
# body_blob: Reinders, H. (2011).  Towards an operationalisation of autonomy. ...
# metadata_blob: {'page': '10.0', 'source': 'temp.pdf'}
#
# Row 1699:
# row_id: 73399ee7992c4685bbb73704681dec38
# embedding_vector: [-0.251220703125, 2.22265625, 1.17578125, 0.005825042724609375,  ...
# body_blob: This type of analysis involved counting the number of the interv ...
# metadata_blob: {'page': '4.0', 'source': 'temp.pdf'}
#
# Row 1700:
# row_id: 22534d2bee3c4dfb9afa9b56eaf52881
# embedding_vector: [-0.27099609375, 2.40234375, 0.2364501953125, -0.63671875, 2.302 ...
# body_blob: stressed by many of the interviewees, learning English vocabular ...
# metadata_blob: {'page': '7.0', 'source': 'temp.pdf'}
#
# Row 1701:
# row_id: d586b8bf4b544ecb923250a98c6037ce
# embedding_vector: [-0.5400390625, -0.90283203125, -0.1932373046875, -0.43676757812 ...
# body_blob: and 12.21 - year 2, MA). The proficiency level represented by th ...
# metadata_blob: {'page': '3.0', 'source': 'temp.pdf'}
#
# Row 1702:
# row_id: 51cc82f237b8427dbb90916dddd06b12
# embedding_vector: [1.5361328125, 1.30859375, 1.6884765625, -1.8818359375, 1.003906 ...
# body_blob: ha v e
# enhanced
# my
# skills
# in
# designing
# landing
# pages
# and
# incorpo ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1703:
# row_id: 8e95151cc5794b7eb8d6db09309a64b0
# embedding_vector: [0.71875, 0.80419921875, 1.62890625, -2.626953125, -0.4375, -1.7 ...
# body_blob: eﬃciently ,
# balancing
# both
# my
# academic
# r esponsibilities
# with
# me ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1704:
# row_id: 8ff4ab3586454beb84da5f27decd6653
# embedding_vector: [0.69580078125, 0.70751953125, 1.5556640625, -1.212890625, 0.642 ...
# body_blob: a
# landing
# page
# tr anslated
# int o
# F r ench.
# 19.
# Re viewed
# US
# Inte ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1705:
# row_id: d010f87264814268860a62e42e043aa8
# embedding_vector: [-0.32568359375, 1.25390625, 1.26171875, -0.62060546875, 1.46777 ...
# body_blob: Byrne, J. & Diem, R. (2014). Profiling mobile English language l ...
# metadata_blob: {'page': '9.0', 'source': 'temp.pdf'}
#
# Row 1706:
# row_id: 02e6fdf5aa784b10933176072aa57c0d
# embedding_vector: [0.378662109375, 0.6630859375, 2.890625, -0.86328125, 0.68603515 ...
# body_blob: should prepare them for effective usage of such devices for this ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1707:
# row_id: 356c15cf916a470382493824f7772eb9
# embedding_vector: [0.71875, 0.80419921875, 1.62890625, -2.626953125, -0.4375, -1.7 ...
# body_blob: eﬃciently ,
# balancing
# both
# my
# academic
# r esponsibilities
# with
# me ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1708:
# row_id: ff58f333128d48c08df3fe76dd9831e3
# embedding_vector: [-0.39697265625, 2.072265625, 1.6376953125, -0.66943359375, 1.88 ...
# body_blob: distance language learning (e.g. Demouy, Jones, Kan, Kukulska -H ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1709:
# row_id: 2957a5decd8845f89864c83564a2308d
# embedding_vector: [1.2236328125, 0.2359619140625, 0.1490478515625, -0.3076171875,  ...
# body_blob: in
# the
# USA,
# EU,
# and
# A ustr alia.
# 2.
# Inv estigated
# the
# eff ectiv  ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1710:
# row_id: 317353ce194d42439f2bb7175f045eb7
# embedding_vector: [1.708984375, 0.953125, 0.96533203125, -0.66552734375, -0.617187 ...
# body_blob: S13 female  smartphone  3 years  not very experienced
# S14 male ...
# metadata_blob: {'page': '5.0', 'source': 'test.pdf'}
#
# Row 1711:
# row_id: 087d42664e3b4534a4b4cf73f990828d
# embedding_vector: [-0.246337890625, 0.325439453125, 1.21484375, -0.376953125, 1.72 ...
# body_blob: individuals need to be increasingly adept at critical adaptive l ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1712:
# row_id: f2abad29be644e69a73e729cf69a66e5
# embedding_vector: [0.05316162109375, 1.109375, -0.485595703125, -1.0009765625, 0.8 ...
# body_blob: training not  only in the area of technology -mediated language  ...
# metadata_blob: {'page': '8.0', 'source': 'temp.pdf'}
#
# Row 1713:
# row_id: f61ae34491aa47b6b4a29f581fec56e0
# embedding_vector: [0.228515625, 0.381591796875, 2.107421875, 0.1624755859375, 2.16 ...
# body_blob: classes. Such a state of affairs can be explained in terms of in ...
# metadata_blob: {'page': '8.0', 'source': 'temp.pdf'}
#
# Row 1714:
# row_id: f2db8d2712724ac4bf9f81f7fd3d27c9
# embedding_vector: [-1.4951171875, -0.322998046875, -0.89697265625, -1.529296875, 0 ...
# body_blob: The EUROCALL Review,  Volume 25, No. 2, September 2017
#
#  21 3 ...
# metadata_blob: {'page': '3.0', 'source': 'test.pdf'}
#
# Row 1715:
# row_id: 41618d7d5367477baa562c3d7de0233b
# embedding_vector: [0.3369140625, 1.3076171875, 1.94140625, -1.787109375, -0.210815 ...
# body_blob: latest
# tr ends
# in
# the
# ﬁeld
# will
# be
# crucial.
# F ur thermor e,
# I
# as ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1716:
# row_id: e2d35e7975d14af186fd30af6ae055b6
# embedding_vector: [1.19140625, 0.775390625, 1.328125, -2.37890625, 1.6904296875, - ...
# body_blob: then
# testing
# e v er ything.
# Also,
# collecting
# r eliable
# data
# was
#  ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1717:
# row_id: 65c6bf0b761a4818bd1a3e1b26d452d2
# embedding_vector: [-1.7666015625, 0.74658203125, 1.8310546875, -0.2178955078125, 1 ...
# body_blob: Keengwe (Ed.),  Promoting active learning thr ough the integrati ...
# metadata_blob: {'page': '9.0', 'source': 'temp.pdf'}
#
# Row 1718:
# row_id: d4114b7c75064739a93f365bb5f2da04
# embedding_vector: [-0.56103515625, -0.5302734375, 2.6875, -0.0032672882080078125,  ...
# body_blob: they can be defined as “any device that is small, autonomous and ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1719:
# row_id: 01cb89ef48b746189d98f580d6b48e6e
# embedding_vector: [-0.246337890625, 0.325439453125, 1.21484375, -0.376953125, 1.72 ...
# body_blob: individuals need to be increasingly adept at critical adaptive l ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1720:
# row_id: 2d11ca484e1f47c0b3e80c63a9c68603
# embedding_vector: [0.329345703125, -0.3359375, 1.86328125, -1.7021484375, -1.42285 ...
# body_blob: principles.
# I’v e
# gained
# knowledge
# on
# eff ectiv ely
# using
# CRM
# an ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1721:
# row_id: 3a473b269152403fbff20cbdeadcbb5c
# embedding_vector: [-1.001953125, 0.99462890625, 0.37646484375, -0.307861328125, 1. ...
# body_blob: spelling and also listen to pronunciation (How about phonetic tr ...
# metadata_blob: {'page': '7.0', 'source': 'temp.pdf'}
#
# Row 1722:
# row_id: cd831666e3e84b04b68da39378d8ea23
# embedding_vector: [0.71875, 0.80419921875, 1.62890625, -2.626953125, -0.4375, -1.7 ...
# body_blob: eﬃciently ,
# balancing
# both
# my
# academic
# r esponsibilities
# with
# me ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1723:
# row_id: 7645c7b4b21d4f41a5573a1722417c4a
# embedding_vector: [-0.8720703125, 0.5478515625, 0.8408203125, -0.61083984375, 3.48 ...
# body_blob: S3: (…) as for vocabulary I guess it’s much faster to search for ...
# metadata_blob: {'page': '7.0', 'source': 'temp.pdf'}
#
# Row 1724:
# row_id: 18985e6d854c496ca4faf7b2695b8679
# embedding_vector: [0.343994140625, 1.3056640625, 1.9443359375, -1.7900390625, -0.2 ...
# body_blob: latest
# tr ends
# in
# the
# ﬁeld
# will
# be
# crucial.
# F ur thermor e,
# I
# as ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1725:
# row_id: b2cfe5a633a54400aac1249bff1d4b88
# embedding_vector: [-0.05474853515625, 2.3125, 1.0771484375, -2.74609375, 0.2729492 ...
# body_blob: enhanced
# my
# skill
# set
# but
# also
# br oadened
# my
# understanding
# of
# cr ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1726:
# row_id: 4da34b4394ed40f79bc5ddd62845b2da
# embedding_vector: [-1.974609375, 0.8232421875, 0.6640625, -1.001953125, 1.17675781 ...
# body_blob: S19: Yes, I use my smartphone and tablet for out -of-class learn ...
# metadata_blob: {'page': '6.0', 'source': 'temp.pdf'}
#
# Row 1727:
# row_id: 05e3e57d7ddc404683124c3a473ac3c3
# embedding_vector: [0.95068359375, 1.3017578125, 1.353515625, 0.78466796875, 0.4667 ...
# body_blob: S20: Fiszkoteka. I frequently use this app (...) I also listen t ...
# metadata_blob: {'page': '6.0', 'source': 'temp.pdf'}
#
# Row 1728:
# row_id: ceb725d3d4fc489d828e3a9a3c98c4e6
# embedding_vector: [0.72509765625, 1.96875, 1.958984375, -2.361328125, 1.2333984375 ...
# body_blob: 2.
# Accomplishments
# Thr oughout
# my
# internship,
# I
# dedicated
# myself ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1729:
# row_id: 39c3bf57c7b445c286a917c72b90b0a7
# embedding_vector: [0.8125, 1.3076171875, 1.384765625, -2.669921875, -1.2333984375, ...
# body_blob: of
# the
# landing
# page
# in
# r elation
# t o
# CRM
# and
# pa yment
# integr ati ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 1730:
# row_id: 68a99049bbb9459e9108eb3353a295da
# embedding_vector: [-2.53125, -1.1513671875, 0.5078125, 1.0283203125, 0.49267578125 ...
# body_blob: other authors autonomy also involves “a capacity – for detachmen ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1731:
# row_id: 03216698f93c40c2a8ef50a47fb1ba4e
# embedding_vector: [0.62744140625, -0.240966796875, 2.52734375, -2.8046875, 0.79638 ...
# body_blob: Event Name: Abdul Bari( Algorithmic Brilliance: Expert insights  ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 1732:
# row_id: a091de18a24d4650a078aa8772a5ce78
# embedding_vector: [-0.058990478515625, 0.2159423828125, -0.7578125, 0.94384765625, ...
# body_blob: person, the setting, and multiple contextual and micro -contextu ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1733:
# row_id: f6c30286841a480781d7bc734ed56c7d
# embedding_vector: [-1.2490234375, 1.00390625, 1.64453125, -0.266357421875, 0.82470 ...
# body_blob: rather intuitive and perhaps even spontaneous use of their mobil ...
# metadata_blob: {'page': '8.0', 'source': 'temp.pdf'}
#
# Row 1734:
# row_id: 97592b320dbe4353bfc872107cd5dc14
# embedding_vector: [0.421630859375, 0.07373046875, 2.158203125, -1.236328125, 1.989 ...
# body_blob: by offering or designing tasks devoted to practicing a variety o ...
# metadata_blob: {'page': '8.0', 'source': 'temp.pdf'}
#
# Row 1735:
# row_id: 6589da342a8e44b184fc8bda41a28bf5
# embedding_vector: [0.329345703125, -0.3359375, 1.86328125, -1.7021484375, -1.42285 ...
# body_blob: principles.
# I’v e
# gained
# knowledge
# on
# eff ectiv ely
# using
# CRM
# an ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1736:
# row_id: 898c6a00c41540e6be731c451f5860e1
# embedding_vector: [-0.5400390625, 0.246337890625, 0.453857421875, -1.7216796875, 1 ...
# body_blob: since they were accessible to the researcher (Dörnyei, 2007, p.  ...
# metadata_blob: {'page': '10.0', 'source': 'temp.pdf'}
#
# Row 1737:
# row_id: f15acba77672462e8e49e514033b0ba4
# embedding_vector: [0.329345703125, -0.3359375, 1.86328125, -1.7021484375, -1.42285 ...
# body_blob: principles.
# I’v e
# gained
# knowledge
# on
# eff ectiv ely
# using
# CRM
# an ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1738:
# row_id: 00d54221b33545ef9df566ac394d89a3
# embedding_vector: [0.042572021484375, 0.59765625, 1.9150390625, 0.568359375, 0.833 ...
# body_blob: devices for lan guage study may result in greater learner engage ...
# metadata_blob: {'page': '9.0', 'source': 'temp.pdf'}
#
# Row 1739:
# row_id: f74f40376438490b8fe7e87db045a8a9
# embedding_vector: [-0.2442626953125, 1.0595703125, 2.048828125, -1.322265625, 1.52 ...
# body_blob: S12: I think I’m quite good at grammar and I practice listening  ...
# metadata_blob: {'page': '7.0', 'source': 'temp.pdf'}
#
# Row 1740:
# row_id: 92cee0c70bdb43a8bedc1b887f0d9fae
# embedding_vector: [-1.3740234375, 1.4580078125, -0.59375, -0.43212890625, 0.542480 ...
# body_blob: learning: From content delivery to supported collaboration and
#  ...
# metadata_blob: {'page': '9.0', 'source': 'test.pdf'}
#
# Row 1741:
# row_id: 625596e9fcc444578f7f16c201e588bd
# embedding_vector: [-1.4072265625, 0.9541015625, 2.294921875, -0.246826171875, 0.81 ...
# body_blob: suggested by the interviewees’ teachers during their practical E ...
# metadata_blob: {'page': '6.0', 'source': 'temp.pdf'}
#
# Row 1742:
# row_id: 703b5f72146c44da94982b013a47e550
# embedding_vector: [-1.2578125, -1.705078125, 0.880859375, -1.28515625, 2.046875, - ...
# body_blob: fact that  “autonomous learners always do things for themselves, ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 1743:
# row_id: d0fe6f1956674052a5b2a43c3fc750dd
# ...
# embedding_vector: [-0.5400390625, 0.246337890625, 0.453857421875, -1.7216796875, 1 ...
# body_blob: since they were accessible to the researcher (Dörnyei, 2007, p.  ...
# metadata_blob: {'page': '10.0', 'source': 'test.pdf'}
#
# Row 2096:
# row_id: 9d310a5425f64a69baa90d994508eec5
# embedding_vector: [0.970703125, 1.830078125, 1.5849609375, -1.544921875, 0.6611328 ...
# body_blob: The data were gathered by means of a semi -structured interview. ...
# metadata_blob: {'page': '3.0', 'source': 'temp.pdf'}
#
# Row 2097:
# row_id: 8311f25666a349a3acb0e217dc3c3cfa
# embedding_vector: [-0.27099609375, 2.40234375, 0.2364501953125, -0.63671875, 2.302 ...
# body_blob: stressed by many of the interviewees, learning English vocabular ...
# metadata_blob: {'page': '7.0', 'source': 'temp.pdf'}
#
# Row 2098:
# row_id: eae474f2f6d746bd9d35c701e25ede0c
# embedding_vector: [0.1529541015625, 0.412841796875, 2.478515625, -0.366455078125,  ...
# body_blob: started to be influenced by technology in the mid -1990s as a re ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 2099:
# row_id: fc3a3bb77ebe4a4cb6322f765fa28dd3
# embedding_vector: [0.449462890625, 0.256591796875, 0.677734375, -0.69091796875, 0. ...
# body_blob: it takes me, say, t en seconds (...) this way I can devote less  ...
# metadata_blob: {'page': '7.0', 'source': 'temp.pdf'}
#
# Row 2100:
# row_id: 142963c2c9df4084933217c53854131f
# embedding_vector: [0.78662109375, -0.23681640625, 1.8125, -1.0302734375, 0.8173828 ...
# body_blob: publicity of the event other than regular post on social media.  ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 2101:
# row_id: 29385a94e75d4084b9a7dfc1ae54f28d
# embedding_vector: [-0.919921875, 2.09375, 0.2724609375, -0.70947265625, 1.52050781 ...
# body_blob: instance, the use of chunks of spare time for language practice, ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 2102:
# row_id: c18853ebbd2c450990f862d6571084e1
# embedding_vector: [0.75244140625, 0.6552734375, 1.9267578125, 0.64013671875, 2.347 ...
# body_blob: learning new vocabulary, preparing multimedia presentations and  ...
# metadata_blob: {'page': '6.0', 'source': 'temp.pdf'}
#
# Row 2103:
# row_id: 650b754f9800466d8fc57b822b3ac4a4
# embedding_vector: [-0.1748046875, 2.138671875, 1.8408203125, -3.240234375, 1.77636 ...
# body_blob: the
# r egular
# meetings
# pla y ed
# a
# crucial
# r ole
# in
# k eeping
# me
# al ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 2104:
# row_id: b8bd9107c5bf4e6d9460716a35c16b80
# embedding_vector: [0.09674072265625, 1.3515625, 2.73046875, -2.2578125, 0.48876953 ...
# body_blob: integr ating
# H TML-CSS
# codes,
# and
# forms.
# 3.
# Resear ched
# individu ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 2105:
# row_id: 601adb95bf9347fb8a551c25761f9ce8
# embedding_vector: [-0.251220703125, 2.22265625, 1.17578125, 0.005825042724609375,  ...
# body_blob: This type of analysis involved counting the number of the interv ...
# metadata_blob: {'page': '4.0', 'source': 'test.pdf'}
#
# Row 2106:
# row_id: af8584eb4d7146e49aa01c65b2c4a3bc
# embedding_vector: [-0.806640625, 1.5869140625, 1.54296875, -0.59375, -0.64453125,  ...
# body_blob: number of participants reduces the generalizability of the resul ...
# metadata_blob: {'page': '8.0', 'source': 'test.pdf'}
#
# Row 2107:
# row_id: 47f7cd9a54f44d9c92a9b28e90b6369f
# embedding_vector: [-1.11328125, -0.37451171875, 0.030731201171875, 0.1066284179687 ...
# body_blob: who said:
# If I’m to say that I devote more time for learning E ...
# metadata_blob: {'page': '7.0', 'source': 'temp.pdf'}
#
# Row 2108:
# row_id: 315f58cc6f2e473081f2cb76938311d1
# embedding_vector: [0.05316162109375, 1.109375, -0.485595703125, -1.0009765625, 0.8 ...
# body_blob: training not  only in the area of technology -mediated language  ...
# metadata_blob: {'page': '8.0', 'source': 'test.pdf'}
#
# Row 2109:
# row_id: f1b649fd8abd46f586d3a9132ab57999
# embedding_vector: [-0.56640625, -1.904296875, 0.57763671875, -0.3974609375, 1.7861 ...
# body_blob: Moreover, Littlewood (1996) argues that if an individual is to b ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 2110:
# row_id: db75bec185614c649185002544289903
# embedding_vector: [0.66357421875, 1.1142578125, 0.6630859375, -2.09375, 0.39379882 ...
# body_blob: Performance
# Appraisal
# Self-evaluation
# Template
# Name:
# Sumeet
# Prus ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 2111:
# row_id: 05635e57928349bd997118bff4450eef
# embedding_vector: [-1.4951171875, 0.673828125, 1.724609375, -1.4521484375, 1.57324 ...
# body_blob: S5: It’s because I can find needed information ... it’s convenie ...
# metadata_blob: {'page': '5.0', 'source': 'temp.pdf'}
#
# Row 2112:
# row_id: 11fee06e457c45219af36f84f98e3605
# embedding_vector: [-0.64990234375, 1.4033203125, 1.970703125, -0.67919921875, 1.50 ...
# body_blob:  As far as learning English through your mobile device(s) is co ...
# metadata_blob: {'page': '4.0', 'source': 'test.pdf'}
#
# Row 2113:
# row_id: 6e729c6226c444ab9f6022d2056213bc
# embedding_vector: [-0.6748046875, 0.1412353515625, 1.68359375, -0.3466796875, 0.75 ...
# body_blob: Table 1 shows the study participants’ mobile devices (MobDs) usa ...
# metadata_blob: {'page': '4.0', 'source': 'temp.pdf'}
#
# Row 2114:
# row_id: d9ced034661a4a9f852620796b62e23d
# embedding_vector: [0.970703125, 1.830078125, 1.5849609375, -1.544921875, 0.6611328 ...
# body_blob: The data were gathered by means of a semi -structured interview. ...
# metadata_blob: {'page': '3.0', 'source': 'temp.pdf'}
#
# Row 2115:
# row_id: cb07456b6f254364860b35dca4eb1096
# embedding_vector: [-0.93115234375, 1.16796875, 0.7587890625, -0.9423828125, -0.817 ...
# body_blob: of the students’ responses by the present author. ...
# metadata_blob: {'page': '10.0', 'source': 'temp.pdf'}
#
# Row 2116:
# row_id: 83c19a74ab6d46b692d375b96ad4f865
# embedding_vector: [0.69580078125, 0.70751953125, 1.5556640625, -1.212890625, 0.642 ...
# body_blob: a
# landing
# page
# tr anslated
# int o
# F r ench.
# 19.
# Re viewed
# US
# Inte ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 2117:
# row_id: 7769840ca09a4f11ac5f3f133a3e3df8
# embedding_vector: [1.2236328125, 0.2359619140625, 0.1490478515625, -0.3076171875,  ...
# body_blob: in
# the
# USA,
# EU,
# and
# A ustr alia.
# 2.
# Inv estigated
# the
# eff ectiv  ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 2118:
# row_id: 2db2f3eb56514503bb842d00e64824cc
# embedding_vector: [0.50830078125, 1.4677734375, 2.650390625, 0.012603759765625, 0. ...
# body_blob: them with t he intention of learning English for years. Taking a ...
# metadata_blob: {'page': '8.0', 'source': 'temp.pdf'}
#
# Row 2119:
# row_id: 8f835d85ac154cb0a7d848377c493773
# embedding_vector: [-1.001953125, 0.99462890625, 0.37646484375, -0.307861328125, 1. ...
# body_blob: spelling and also listen to pronunciation (How about phonetic tr ...
# metadata_blob: {'page': '7.0', 'source': 'test.pdf'}
#
# Row 2120:
# row_id: 4d2f7dac3ae0478b86fd875715501a9f
# embedding_vector: [0.421630859375, 0.07373046875, 2.158203125, -1.236328125, 1.989 ...
# body_blob: by offering or designing tasks devoted to practicing a variety o ...
# metadata_blob: {'page': '8.0', 'source': 'temp.pdf'}
#
# Row 2121:
# row_id: 530bf6c8034f4574a606cff7f13e6f25
# embedding_vector: [0.62744140625, -0.240966796875, 2.52734375, -2.8046875, 0.79638 ...
# body_blob: Event Name: Abdul Bari( Algorithmic Brilliance: Expert insights  ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 2122:
# row_id: 824cfb6f9c174c5aab257c11e2ff2848
# embedding_vector: [-1.8662109375, -1.2919921875, 0.053070068359375, 0.693359375, 0 ...
# body_blob: to understand who au tonomous learners are. As Littlewood (1996) ...
# metadata_blob: {'page': '1.0', 'source': 'test.pdf'}
#
# Row 2123:
# row_id: 2910384ecbbd44b4ac2d694cbb1defb4
# embedding_vector: [1.41796875, -0.2117919921875, 1.7587890625, -2.791015625, -0.16 ...
# body_blob: its
# r each.
# 5.
# Successfully
# cr eated
# a
# F r ench
# mark eting
# campa ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 2124:
# row_id: 0bea107193d84ebba2b0bf10d9106dc3
# embedding_vector: [-1.7412109375, -1.6796875, 0.7958984375, 0.4248046875, 1.607421 ...
# body_blob: entitled  Autonomy in Foreign Language Learning  in which the re ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 2125:
# row_id: 03170a93a70d4e52884bdda630560b9b
# embedding_vector: [-0.91650390625, 1.4453125, 0.94140625, 1.158203125, 3.1015625,  ...
# body_blob: check something I don’t understand (...) I installed a dictionar ...
# metadata_blob: {'page': '6.0', 'source': 'test.pdf'}
#
# Row 2126:
# row_id: 12b8e169a98543f09e1e5758f39c8f25
# embedding_vector: [-1.0380859375, 1.595703125, 2.31640625, -0.10052490234375, 1.00 ...
# body_blob: The EUROCALL Review,  Volume 25, No. 2, September 2017
#
#  22  ...
# metadata_blob: {'page': '4.0', 'source': 'temp.pdf'}
#
# Row 2127:
# row_id: c4152c46411441678ce72c45ce6ad28b
# embedding_vector: [-1.0380859375, 1.595703125, 2.31640625, -0.10052490234375, 1.00 ...
# body_blob: The EUROCALL Review,  Volume 25, No. 2, September 2017
#
#  22  ...
# metadata_blob: {'page': '4.0', 'source': 'temp.pdf'}
#
# Row 2128:
# row_id: 95e737ee21a144758fa6f943d185de93
# embedding_vector: [-0.39697265625, 2.072265625, 1.6376953125, -0.66943359375, 1.88 ...
# body_blob: distance language learning (e.g. Demouy, Jones, Kan, Kukulska -H ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 2129:
# row_id: 2b35785038ea4dd08bb7d8045439ff7d
# embedding_vector: [-1.2578125, -1.705078125, 0.880859375, -1.28515625, 2.046875, - ...
# body_blob: fact that  “autonomous learners always do things for themselves, ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 2130:
# row_id: d517a916917241159943f1cbac3880a0
# embedding_vector: [-0.01593017578125, 0.162841796875, 0.64453125, -2.044921875, 1. ...
# body_blob: computer word processor program  Microsoft Word 2016 . Then the  ...
# metadata_blob: {'page': '4.0', 'source': 'temp.pdf'}
#
# Row 2131:
# row_id: fac3588b123c4b78a1fe6d9c589d7668
# embedding_vector: [0.8125, 1.3076171875, 1.384765625, -2.669921875, -1.2333984375, ...
# body_blob: of
# the
# landing
# page
# in
# r elation
# t o
# CRM
# and
# pa yment
# integr ati ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 2132:
# row_id: 3cd3a43e704843748e76bcb7fe0d2e4b
# embedding_vector: [0.09423828125, 0.1478271484375, 1.6923828125, -1.0107421875, 1. ...
# body_blob: The EUROCALL Review,  Volume 25, No. 2, September 2017
#
#  18 R ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 2133:
# row_id: 0ffcb5ce86dc48a0b30f9bc2764516db
# embedding_vector: [-0.82861328125, -0.11712646484375, 3.302734375, -0.7177734375,  ...
# body_blob: useful addition to formal and informal language learning .
# Acco ...
# metadata_blob: {'page': '0.0', 'source': 'test.pdf'}
#
# Row 2134:
# row_id: 1cc6474943ed4be0b47991a5053466a5
# embedding_vector: [-0.2442626953125, 1.0595703125, 2.048828125, -1.322265625, 1.52 ...
# body_blob: S12: I think I’m quite good at grammar and I practice listening  ...
# metadata_blob: {'page': '7.0', 'source': 'test.pdf'}
#
# Row 2135:
# row_id: 769160b3b5084264a68dc7580c4f36ed
# embedding_vector: [-0.39306640625, -0.73388671875, 1.41796875, -0.9482421875, 0.89 ...
# body_blob: from http://eprints.biblio.unitn.it/archive/00000532/01/paper491 ...
# metadata_blob: {'page': '10.0', 'source': 'temp.pdf'}
#
# Row 2136:
# row_id: 62d1eb62ec2341c59964a8a7979f3bc4
# embedding_vector: [1.2236328125, 0.2359619140625, 0.1490478515625, -0.3076171875,  ...
# body_blob: in
# the
# USA,
# EU,
# and
# A ustr alia.
# 2.
# Inv estigated
# the
# eff ectiv  ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 2137:
# row_id: 381583962ba446f8a22d377dc8def3ed
# embedding_vector: [-0.6591796875, 0.931640625, 0.91796875, 0.2181396484375, 2.7929 ...
# body_blob: 4.5. La nguage practiced
# When asked to indicate the most frequ ...
# metadata_blob: {'page': '7.0', 'source': 'temp.pdf'}
#
# Row 2138:
# row_id: 74f4cdc3bd034050996ae49686087c0f
# embedding_vector: [0.8125, 1.3076171875, 1.384765625, -2.669921875, -1.2333984375, ...
# body_blob: of
# the
# landing
# page
# in
# r elation
# t o
# CRM
# and
# pa yment
# integr ati ...
# metadata_blob: {'page': '0.0', 'source': 'temp.pdf'}
#
# Row 2139:
# row_id: 6a6560a8d1bb43b89efdc3a8043c3a45
# embedding_vector: [-0.251220703125, 2.22265625, 1.17578125, 0.005825042724609375,  ...
# body_blob: This type of analysis involved counting the number of the interv ...
# metadata_blob: {'page': '4.0', 'source': 'test.pdf'}
#
# Row 2140:
# row_id: c2b78b2525744b7a94b60370d42e5ff8
# embedding_vector: [0.48583984375, -0.1300048828125, 1.1298828125, -0.47021484375,  ...
# body_blob: 3.80 years (minimum 2, maximum 6 years). 9 (45 %) and 11 (55%) o ...
# metadata_blob: {'page': '4.0', 'source': 'temp.pdf'}
#
# Row 2141:
# row_id: 5cd633680a13422e9118f65f809ba76a
# embedding_vector: [0.490966796875, 1.412109375, 2.8359375, -0.46044921875, 1.32421 ...
# body_blob: devices could be altered if teachers took into account the benef ...
# metadata_blob: {'page': '8.0', 'source': 'temp.pdf'}
#
# Row 2142:
# row_id: 86afd7e84ea44714a61c1733c340c321
# embedding_vector: [-0.230224609375, -0.32763671875, 4.421875, -2.744140625, 1.6044 ...
# body_blob: thus it is difficult to achieve and is not invariably permanent  ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 2143:
# row_id: 88ec4fb72cbe4969bab041b2bde3f83a
# embedding_vector: [-1.046875, 0.318603515625, 2.240234375, -1.1845703125, 2.824218 ...
# body_blob: particular language skills and thus they did  not feel the need  ...
# metadata_blob: {'page': '7.0', 'source': 'temp.pdf'}
#
# Row 2144:
# row_id: d6f1dd19203d481dabf76d17f0de5799
# embedding_vector: [0.50830078125, 1.4677734375, 2.650390625, 0.012603759765625, 0. ...
# body_blob: them with t he intention of learning English for years. Taking a ...
# metadata_blob: {'page': '8.0', 'source': 'temp.pdf'}
#
# Row 2145:
# row_id: 9f9138df10044a76a7cd1bbcc0fd0148
# embedding_vector: [-0.6044921875, 0.475341796875, 3.353515625, 0.447509765625, 1.0 ...
# body_blob: student to learn more (S6:  I’m more willing to use my smartphon ...
# metadata_blob: {'page': '7.0', 'source': 'test.pdf'}
#
# Row 2146:
# row_id: bc98dd345118470f8e2e45ab649aca1b
# embedding_vector: [0.6181640625, -0.047698974609375, 2.869140625, -2.33203125, 2.0 ...
# body_blob: Contribution: Helped in designing the poster for the event , coo ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 2147:
# row_id: 91fb81365bd14cbaa3d85dfc76dae9cb
# embedding_vector: [0.343994140625, 1.3056640625, 1.9443359375, -1.7900390625, -0.2 ...
# body_blob: latest
# tr ends
# in
# the
# ﬁeld
# will
# be
# crucial.
# F ur thermor e,
# I
# as ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 2148:
# row_id: 5cb32dba63544d419ce8f3be25b121c8
# embedding_vector: [0.24462890625, 0.96044921875, 1.2158203125, -0.6748046875, 0.66 ...
# body_blob: learners who do not have direct access to the target language. T ...
# metadata_blob: {'page': '2.0', 'source': 'test.pdf'}
#
# Row 2149:
# row_id: 19ad552860474b6083d3070ab7a79f62
# embedding_vector: [-0.1748046875, 2.138671875, 1.8408203125, -3.240234375, 1.77636 ...
# body_blob: the
# r egular
# meetings
# pla y ed
# a
# crucial
# r ole
# in
# k eeping
# me
# al ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# Row 2150:
# row_id: 4b1edd0aa0cd40328b0458223e05aaf5
# embedding_vector: [0.329345703125, -0.3359375, 1.86328125, -1.7021484375, -1.42285 ...
# body_blob: principles.
# I’v e
# gained
# knowledge
# on
# eff ectiv ely
# using
# CRM
# an ...
# metadata_blob: {'page': '1.0', 'source': 'temp.pdf'}
#
# Row 2151:
# row_id: 4ee7b0034cb44dada64d84b78282b99a
# embedding_vector: [-1.0283203125, 1.1552734375, 0.771484375, -0.9521484375, 0.2286 ...
# body_blob: Technology (LLT)  concerned language learners engagement with te ...
# metadata_blob: {'page': '3.0', 'source': 'temp.pdf'}
#
# Row 2152:
# row_id: 1fb14536984641cd871ebbf5c8568c98
# embedding_vector: [-1.1416015625, -1.6435546875, 0.58984375, -1.22265625, 1.076171 ...
# body_blob: Reinders, H. (2011).  Towards an operationalisation of autonomy. ...
# metadata_blob: {'page': '10.0', 'source': 'temp.pdf'}
#
# Row 2153:
# row_id: 6be83692f4df4122829f4a75f04af96e
# embedding_vector: [0.1949462890625, 0.388916015625, 1.9150390625, 0.0936279296875, ...
# body_blob: of new technologies, particularly those encompassing the interne ...
# metadata_blob: {'page': '2.0', 'source': 'temp.pdf'}
#
# ...

# %% [markdown]
# # Asking questions to PDF

# %%
llm.model = 'command-r-plus'
query_1 = "What is 1+1?"
pdf_index.query_with_sources(query_1, llm=llm)
# Out:
# WARNING:cassandra.protocol:Server warning: Top-K queries can only be run with consistency level ONE / LOCAL_ONE / NODE_LOCAL. Consistency level LOCAL_QUORUM was requested. Downgrading the consistency level to LOCAL_ONE.
# {'question': 'What is 1+1?', 'answer': "I don't know.\n", 'sources': ''}

# %%
llm.model = 'command-r-plus'
query_2 = "What roles did Sumeet play?"
pdf_index.query_with_sources(query_2, llm=llm)
# Out:
# WARNING:cassandra.protocol:Server warning: Top-K queries can only be run with consistency level ONE / LOCAL_ONE / NODE_LOCAL. Consistency level LOCAL_QUORUM was requested. Downgrading the consistency level to LOCAL_ONE.
# {'question': 'What roles did Sumeet play?',
#  'answer': 'Sumeet played a variety of roles in the event, including helping to design the poster and LinkedIn posts, coordinating with the team to manage the crowd, ensuring there were no technical problems, making feedback forms, and helping people with doubts.\n\n',
#  'sources': 'temp.pdf'}

# %%
llm.model = 'command-r-plus'
query_3 = "How does Benson (2011) describe the relationship between educational technologies and learner autonomy?"
pdf_index.query_with_sources(query_3, llm=llm)
# Out:
# WARNING:cassandra.protocol:Server warning: Top-K queries can only be run with consistency level ONE / LOCAL_ONE / NODE_LOCAL. Consistency level LOCAL_QUORUM was requested. Downgrading the consistency level to LOCAL_ONE.
# {'question': 'How does Benson (2011) describe the relationship between educational technologies and learner autonomy?',
#  'answer': 'Benson (2011) describes the relationship between educational technologies and learner autonomy as a connection that has always existed, with educational technologies often being intended for independent practice.\n',
#  'sources': 'temp.pdf, test.pdf'}

# %%
llm.model = 'command-r-plus'
query_4 = "Why should language teachers equip learners with knowledge about mobile devices?"
pdf_index.query_with_sources(query_4, llm=llm)
# Out:
# WARNING:cassandra.protocol:Server warning: Top-K queries can only be run with consistency level ONE / LOCAL_ONE / NODE_LOCAL. Consistency level LOCAL_QUORUM was requested. Downgrading the consistency level to LOCAL_ONE.
# {'question': 'Why should language teachers equip learners with knowledge about mobile devices?',
#  'answer': "Language teachers should equip learners with knowledge about mobile devices because these devices are ubiquitous and substantial constituents of almost every language learner's everyday life.\n",
#  'sources': 'test.pdf, temp.pdf'}

# %%
llm.model = 'command-r-plus'
query_5 = "What does Reinders (2011) suggest about the continuum of autonomy in language learning?"
pdf_index.query_with_sources(query_5, llm=llm)
# Out:
# WARNING:cassandra.protocol:Server warning: Top-K queries can only be run with consistency level ONE / LOCAL_ONE / NODE_LOCAL. Consistency level LOCAL_QUORUM was requested. Downgrading the consistency level to LOCAL_ONE.
# {'question': 'What does Reinders (2011) suggest about the continuum of autonomy in language learning?',
#  'answer': 'Reinders (2011) suggests that autonomy in language learning is not an either-or concept, but a continuum. This means that a learner can display varying levels of autonomy in different learning situations, and that autonomy can change over time within and between skills.\n',
#  'sources': 'test.pdf, temp.pdf'}

# %%
llm.model = 'command-r-plus'
query_6 = "What is 1+1?"
pdf_index.query_with_sources(query_6, llm=llm)
# Out:
# WARNING:cassandra.protocol:Server warning: Top-K queries can only be run with consistency level ONE / LOCAL_ONE / NODE_LOCAL. Consistency level LOCAL_QUORUM was requested. Downgrading the consistency level to LOCAL_ONE.
# {'question': 'What is 1+1?', 'answer': "I don't know.\n", 'sources': ''}

# %%
llm.model = 'command-r-plus'
query_7 = "What new features did you work on in Swipe Pages?"
pdf_index.query_with_sources(query_7, llm=llm)
# Out:
# WARNING:cassandra.protocol:Server warning: Top-K queries can only be run with consistency level ONE / LOCAL_ONE / NODE_LOCAL. Consistency level LOCAL_QUORUM was requested. Downgrading the consistency level to LOCAL_ONE.
# {'question': 'What new features did you work on in Swipe Pages?',
#  'answer': 'The new features worked on in Swipe Pages include a sliding testimonial feature, a form feature, and integration with Zoho and Razorpay.\n\n',
#  'sources': 'temp.pdf, Sumeet.pdf'}

# %%
llm.model = 'command-r-plus'
query_8 = "Please give the summary of test.pdf?"
pdf_index.query_with_sources(query_8, llm=llm)
# Out:
# WARNING:cassandra.protocol:Server warning: Top-K queries can only be run with consistency level ONE / LOCAL_ONE / NODE_LOCAL. Consistency level LOCAL_QUORUM was requested. Downgrading the consistency level to LOCAL_ONE.
# {'question': 'Please give the summary of test.pdf?',
#  'answer': "The document is a performance appraisal self-evaluation template for an intern named Sumeet Prusty, who worked as a marketing analyst intern from January 14, 2024, to April 30, 2024. Sumeet's tasks during the internship included researching data on individuals seeking higher education, particularly those preparing for visa interviews in the USA, EU, and other countries.\n\n",
#  'sources': 'temp.pdf'}

# %%
# !pip install pymupdf
import fitz
import cohere
import time
# Out:
# Collecting pymupdf
#   Downloading PyMuPDF-1.24.7-cp310-none-manylinux2014_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 29.4 MB/s eta 0:00:00
# Collecting PyMuPDFb==1.24.6 (from pymupdf)
#   Downloading PyMuPDFb-1.24.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 77.2 MB/s eta 0:00:00
# Installing collected packages: PyMuPDFb, pymupdf
# Successfully installed PyMuPDFb-1.24.6 pymupdf-1.24.7

# %%
api_key = COHERE_API_KEY
co = cohere.Client(api_key)

# %%
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page_num in range(doc.page_count):
        page = doc.load_page(page_num)
        text += page.get_text("text")
    return text

# %%
def chunk_text(text, max_chunk_size=3000):
    words = text.split()
    chunks = []
    current_chunk = []
    current_length = 0

    for word in words:
        current_length += len(word) + 1
        if current_length > max_chunk_size:
            chunks.append(" ".join(current_chunk))
            current_chunk = [word]
            current_length = len(word) + 1
        else:
            current_chunk.append(word)

    if current_chunk:
        chunks.append(" ".join(current_chunk))

    return chunks

# %%
def summarize_text_with_cohere(text):
    chunks = chunk_text(text)
    summary = ""
    for chunk in chunks:
        response = co.summarize(text=chunk, length='medium')
        summary += response.summary + " "
        time.sleep(12)
    return summary.strip()

# %%
pdf_files = ["test.pdf"]
summaries = {}

for pdf_file in pdf_files:
    text = extract_text_from_pdf(pdf_file)
    summary = summarize_text_with_cohere(text)
    summaries[pdf_file] = summary

for pdf, summary in summaries.items():
    print(f"Summary for {pdf}:\n{summary}\n")
# Out:
# Summary for test.pdf:
# The study explores the use of mobile devices by advanced learners of English. The data, collected from 20 students by means of a semi-structured interview, were subjected to qualitative and quantitative analysis. The results show that, while some students are aware of the benefits of mobile devices for language learning and can retrieve necessary information to adjust their learning to their personal learning styles, others use their mobile devices rather intuitively and/or ad hoc in the classroom. The paper discusses the implications for research and teaching. This study investigates the use of mobile devices (smartphones and tablets) in the context of English language learning. Specifically, it focuses on the ways in which advanced English language students use their mobile devices for their learning. The study is based on the concept of autonomy in language learning, which suggests that learners are able to take control of their own learning. The study found that while mobile devices offer a range of potential learning opportunities, their effectiveness depends on the learners' ability to self-regulate their use and to make effective use of the available resources. The study also highlights the importance of social interactions and collaborative learning in supporting autonomy in mobile language learning. This article reviews literature related to the concept of learner autonomy in the context of second/foreign language education. The first part of the article provides a brief overview of the main concepts and principles related to the notion of learner autonomy. The second part focuses on the relationship between learner autonomy and new technologies. The article concludes by arguing that new technologies create new opportunities for both teachers and learners and therefore should be implemented in language learning and teaching. The extensive use of new technologies, particularly mobile technology, allows students to avoid classrooms and instead interact directly with target languages through the internet and social media, according to Benson (2011). Mobile technology, including smartphones and tablet computers, allows learners to access a wide range of language resources whenever they need them. These devices also allow learners to take control of their learning, pursue personal interests, and engage in language activities that meet their individual needs and goals. This article discusses the potential role of mobile devices in autonomous language learning. The aim of the present study was to investigate Polish students' use of mobile devices for the purpose of English language learning, as well as their views on the potential of mobile technology for learning and their willingness to use it for this purpose. Data was collected via semi-structured interviews with 20 students of English philology at a Polish university. The findings revealed that the participants did use their mobile devices for English language learning, although this was limited and they were generally reluctant to use their own devices for educational purposes. The students reported a number of benefits associated with the use of mobile technology for language learning, particularly the possibility to use mobile devices anytime and anywhere. The findings are discussed in relation to the literature on the subject. The aim of this paper is to present the results of a qualitative study concerning the use of mobile devices for English study. The data were collected through semi-structured interviews with students of English at a university in the western part of Poland. The obtained data were analyzed qualitatively and quantitatively. The analysis of the interview transcripts resulted in the emergence of several thematic categories. The most important findings show that the majority of students use mobile devices for English study and they use them very often for various purposes and at various times of the day. They also learn English through mobile apps. ...
